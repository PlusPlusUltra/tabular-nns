# %%
#!/usr/bin/env python3

import os
import json
import time
import numpy as np
import pandas as pd

from pathlib import Path

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, mean_squared_error

from sklearn.ensemble import IsolationForest
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

from sklearn.neighbors import LocalOutlierFactor

from sklearn.svm import OneClassSVM

from sklearn.linear_model import LogisticRegression, LinearRegression

from sklearn.neural_network import MLPClassifier, MLPRegressor

from xgboost import XGBClassifier, XGBRegressor


########################################
# CONFIG
########################################

DATA_PATH="data"

DATASETS=[
    "cmc"
]

MODELS=[
    "mlp",
    "xgboost",
    "randomforest"
]

OUTLIERS=[
    None,
    "ZScore",
    "IsolationForest",
    "IQR"
]

RUNS=5


########################################
# DATA LOADING
########################################

def load_json(path):

    return json.loads(Path(path).read_text())


def load_dataset(dataset):

    base=Path(DATA_PATH)/dataset

    def load_block(name):

        return {
            x:np.load(base/f"{name}_{x}.npy",
            allow_pickle=True)

            for x in ["train","val","test"]
        }

    N=load_block("N") if (base/"N_train.npy").exists() else None

    C=load_block("C") if (base/"C_train.npy").exists() else None

    y=load_block("y")

    info=load_json(base/"info.json")

    return N,C,y,info


########################################
# PREPROCESSING
########################################

def preprocess_train(X):

    X = pd.DataFrame(X)

    numeric_cols = X.select_dtypes(include=[np.number]).columns

    means = {}
    stds = {}

    for col in numeric_cols:

        mean = X[col].mean()

        X[col] = X[col].fillna(mean)

        std = X[col].std()

        if std == 0:
            std = 1

        X[col] = (X[col] - mean) / std

        means[col] = mean
        stds[col] = std

    return X.values, means, stds


def preprocess_test(X,means,stds):

    X = pd.DataFrame(X)

    for col in means:

        if col in X:

            X[col] = X[col].fillna(means[col])

            X[col] = (X[col] - means[col]) / stds[col]

    return X.values


########################################
# OUTLIERS
########################################

def detect_outliers(X, method, seed):

    CONTAMINATION = 0.05
    ZSCORE_THRESHOLD = 3
    IQR_FACTOR = 1.5

    if method is None:
        return np.ones(len(X), dtype=bool)

    df = pd.DataFrame(X)

    numeric_df = df.select_dtypes(include=[np.number])

    if numeric_df.shape[1] == 0:
        return np.ones(len(X), dtype=bool)

    numeric_data = numeric_df.values

    

    if method == "ZScore":

        mean = numeric_data.mean(axis=0)

        std = numeric_data.std(axis=0) + 1e-9

        z = np.abs((numeric_data - mean)/std)

        return (z < ZSCORE_THRESHOLD).all(axis=1)


    if method == "IQR":

        Q1 = np.percentile(numeric_data,25,axis=0)

        Q3 = np.percentile(numeric_data,75,axis=0)

        IQR = Q3-Q1

        lower = Q1 - IQR_FACTOR*IQR

        upper = Q3 + IQR_FACTOR*IQR

        return (
            (numeric_data>=lower)&
            (numeric_data<=upper)
        ).all(axis=1)


    if method == "IsolationForest":

        clf = IsolationForest(

            n_estimators=200,

            contamination=CONTAMINATION,

            random_state=seed

        )

        return clf.fit_predict(numeric_data)==1


    if method == "OneClassSVM":

        clf = OneClassSVM(

            nu=CONTAMINATION,

            kernel="rbf",

            gamma="scale"

        )

        

        return clf.fit_predict(numeric_data)==1
    


    raise ValueError("Unknown method")


########################################
# MODELS
########################################

def make_model(name,task,seed):

    name=name.lower()

    if name=="mlp":

        if task=="classification":

            return MLPClassifier(
                hidden_layer_sizes=(100,),
                max_iter=500,
                random_state=seed,
                shuffle=True
            )

        return MLPRegressor(
            hidden_layer_sizes=(100,),
            max_iter=500,
            random_state=seed
        )

    if name=="xgboost":

        if task=="classification":

            return XGBClassifier(
                use_label_encoder=False,
                eval_metric="logloss",
                random_state=seed
            )

        return XGBRegressor(random_state=seed)

    if name=="randomforest":

        if task=="classification":

            return RandomForestClassifier(
                n_estimators=100,
                random_state=seed
            )

        return RandomForestRegressor(
            n_estimators=100,
            random_state=seed
        )

    if name=="linear":

        if task=="classification":

            return LogisticRegression(max_iter=1000)

        return LinearRegression()

    raise ValueError("Unknown model")


########################################
# SINGLE RUN
########################################

def single_run(dataset,model_name,outlier_method,seed):

    np.random.seed(seed)

    N,C,y,info = load_dataset(dataset)

    y_train = y["train"].ravel()
    y_test = y["test"].ravel()

    # Shuffle training data
    perm = np.random.permutation(len(y_train))

    y_train = y_train[perm]
    N["train"] = N["train"][perm]

    if C is not None:
        C["train"] = C["train"][perm]

    # Detect outliers ONLY on numeric features BEFORE preprocessing
    before = len(N["train"])

    mask = detect_outliers(
        N["train"],
        outlier_method,
        seed
    )

    # Apply mask everywhere
    N["train"] = N["train"][mask]
    y_train = y_train[mask]

    if C is not None:
        C["train"] = C["train"][mask]

    after = len(N["train"])

    removed = before - after

    # Build feature matrices AFTER removal
    if C is not None:

        X_train = np.hstack([
            N["train"],
            C["train"]
        ])

        X_test = np.hstack([
            N["test"],
            C["test"]
        ])

    else:

        X_train = N["train"]
        X_test = N["test"]

    # Preprocess AFTER outlier removal
    X_train,means,stds = preprocess_train(X_train)

    X_test = preprocess_test(
        X_test,
        means,
        stds
    )

    # Shuffle again for NN stability
    perm = np.random.permutation(len(X_train))

    X_train = X_train[perm]
    y_train = y_train[perm]

    task = info["task_type"]

    if task != "regression":
        task = "classification"

    if task == "classification":

        le = LabelEncoder()

        y_train = le.fit_transform(y_train)

        y_test = le.transform(y_test)

    model = make_model(
        model_name,
        task,
        seed
    )

    start = time.time()

    model.fit(X_train,y_train)

    train_time = time.time() - start

    score = evaluate(
        model,
        X_test,
        y_test,
        task
    )

    return {

        "score":score,

        "train_before":before,

        "train_after":after,

        "removed":removed,

        "removed_pct": removed / before if before > 0 else 0,

        "time":train_time
    }

########################################
# EVALUATION
########################################

def evaluate(model,X,y,task):

    pred=model.predict(X)

    if task=="classification":

        return accuracy_score(y,pred)

    return mean_squared_error(y,pred)


########################################
# EXPERIMENT LOOP
########################################

def run_experiment(dataset,model,outlier):

    scores=[]
    removed=[]
    removed_pct=[]
    times=[]
    train_sizes=[]

    for i in range(RUNS):

        seed=42+i

        result=single_run(

            dataset,
            model,
            outlier,
            seed
        )

        scores.append(result["score"])

        removed.append(result["removed"])

        removed_pct.append(result["removed_pct"])

        times.append(result["time"])

        train_sizes.append(result["train_before"])

    scores=np.array(scores)

    return {

        "mean":scores.mean(),

        "std":scores.std(),

        "min":scores.min(),

        "max":scores.max(),

        "train_size":int(np.mean(train_sizes)),

        "removed_mean":np.mean(removed),

        "removed_pct":np.mean(removed_pct),

        "time_mean":np.mean(times),

        "all":scores.tolist()
    }


########################################
# LOGGING
########################################

def init_logs():

    os.makedirs("results",exist_ok=True)

    if not os.path.exists("results/summary.csv"):

        with open("results/summary.csv","w") as f:

            f.write(
            "dataset,model,outlier,mean,std,min,max,train_size,removed,removed_pct,time\n"
            )

    if not os.path.exists("results/runs.csv"):

        with open("results/runs.csv","w") as f:

            f.write(
            "dataset,model,outlier,run,seed,score\n"
            )


def log_summary(dataset,model,outlier,res):

    with open("results/summary.csv","a") as f:

        f.write(

        f"{dataset},{model},{outlier},"
        f"{res['mean']:.5f},"
        f"{res['std']:.5f},"
        f"{res['min']:.5f},"
        f"{res['max']:.5f},"
        f"{res['train_size']},"
        f"{res['removed_mean']:.2f},"
        f"{res['removed_pct']:.4f},"
        f"{res['time_mean']:.3f}\n"

        )


def log_runs(dataset,model,outlier,res):

    with open("results/runs.csv","a") as f:

        for i,score in enumerate(res["all"]):

            seed=42+i

            f.write(

            f"{dataset},{model},{outlier},{i},{seed},{score:.5f}\n"

            )


########################################
# MAIN
########################################

def main():

    init_logs()

    for dataset in DATASETS:

        for model in MODELS:

            for outlier in OUTLIERS:

                print("\nRunning:",dataset,model,outlier)

                res=run_experiment(

                    dataset,
                    model,
                    outlier
                )

                print("Mean:",res["mean"])
                print("Std:",res["std"])
                print("Train size:",res["train_size"])
                print("Removed:",res["removed_mean"])
                print("Removed %:",res["removed_pct"])

                log_summary(

                    dataset,
                    model,
                    outlier,
                    res
                )

                log_runs(

                    dataset,
                    model,
                    outlier,
                    res
                )


if __name__=="__main__":

    main()
# Out:
# Running: cmc mlp None
# Mean: 0.5850847457627119
# Std: 0.007906375450637698
# Train size: 942
# Removed: 0.0
# Removed %: 0.0
#
# Running: cmc mlp ZScore
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Mean: 0.5884745762711865
# Std: 0.0034569623820967965
# Train size: 942
# Removed: 14.0
# Removed %: 0.014861995753715499
#
# Running: cmc mlp IsolationForest
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Mean: 0.5803389830508474
# Std: 0.0044971183598039415
# Train size: 942
# Removed: 47.2
# Removed %: 0.05010615711252654
#
# Running: cmc mlp IQR
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Mean: 0.5830508474576271
# Std: 0.010055862355383971
# Train size: 942
# Removed: 58.0
# Removed %: 0.06157112526539278
#
# Running: cmc xgboost None
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:12] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:12] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:12] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:12] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:13] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Mean: 0.511864406779661
# Std: 0.0
# Train size: 942
# Removed: 0.0
# Removed %: 0.0
#
# Running: cmc xgboost ZScore
# Numeric columns: 2
# Numeric columns: 2
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:13] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:13] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:13] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:13] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:13] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Mean: 0.511864406779661
# Std: 0.0
# Train size: 942
# Removed: 14.0
# Removed %: 0.014861995753715499
#
# Running: cmc xgboost IsolationForest
# Numeric columns: 2
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:14] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Numeric columns: 2
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:14] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Numeric columns: 2
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:14] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Numeric columns: 2
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:15] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Numeric columns: 2
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:15] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:15] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Mean: 0.52
# Std: 0.015696050037681653
# Train size: 942
# Removed: 47.2
# Removed %: 0.05010615711252654
#
# Running: cmc xgboost IQR
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:15] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:15] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:15] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Numeric columns: 2
# Numeric columns: 2
# Mean: 0.4847457627118644
# Std: 0.0
# Train size: 942
# Removed: 58.0
# Removed %: 0.06157112526539278
#
# Running: cmc randomforest None
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:32:15] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Mean: 0.5206779661016949
# Std: 0.007906375450637701
# Train size: 942
# Removed: 0.0
# Removed %: 0.0
#
# Running: cmc randomforest ZScore
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Mean: 0.5206779661016949
# Std: 0.004598189819067971
# Train size: 942
# Removed: 14.0
# Removed %: 0.014861995753715499
#
# Running: cmc randomforest IsolationForest
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Mean: 0.528135593220339
# Std: 0.007238697120021241
# Train size: 942
# Removed: 47.2
# Removed %: 0.05010615711252654
#
# Running: cmc randomforest IQR
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Numeric columns: 2
# Mean: 0.5213559322033898
# Std: 0.007848025018840854
# Train size: 942
# Removed: 58.0
# Removed %: 0.06157112526539278

# %%
res = run_experiment(
    dataset="electricity",
    model="xgboost",
    outlier=None
)

print("\nRESULT:")
print("Mean:", res["mean"])
print("Std:", res["std"])
print("All runs:", res["all"])
# Out:
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:51] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# RESULT:
# Mean: 0.7837360697340836
# Std: 0.0
# All runs: [0.7837360697340836, 0.7837360697340836, 0.7837360697340836, 0.7837360697340836, 0.7837360697340836]

# %%
run_experiment("cmc","mlp",None)
# Out:
# {'mean': np.float64(0.5850847457627119),
#  'std': np.float64(0.007906375450637698),
#  'min': np.float64(0.576271186440678),
#  'max': np.float64(0.5966101694915255),
#  'removed_mean': np.float64(0.0),
#  'time_mean': np.float64(0.26859517097473146),
#  'all': [0.576271186440678,
#   0.5864406779661017,
#   0.5966101694915255,
#   0.5898305084745763,
#   0.576271186440678]}
