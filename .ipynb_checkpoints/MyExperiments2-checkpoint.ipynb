# %%
#!/usr/bin/env python3

import os
import json
import time
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

from pathlib import Path

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, mean_squared_error

from sklearn.ensemble import IsolationForest
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

from sklearn.neighbors import LocalOutlierFactor

from sklearn.neural_network import MLPClassifier, MLPRegressor

from xgboost import XGBClassifier, XGBRegressor


########################################
# CONFIG
########################################

DATA_PATH="data"

DATASETS=[
"Bank_Customer_Churn_Dataset",
"cmc",
"connect-4",
"credit-g",
"electricity",
"elevators",
"eucalyptus",
"eye_movements",
"house_16H",
"kc1",
"phoneme",
"pol",
"socmob",
"splice",
"vehicle"
]

MODELS=[
"mlp",
"xgboost",
"randomforest"
]

OUTLIERS=[
None,
"ZScore",
"Percentile",
"IsolationForest",
"LOF",
"Autoencoder"
]

TREATMENTS=[
"remove",
"clip"
]

RUNS=5

CONTAMINATION=0.05

LOW_PCTL=5
HIGH_PCTL=95


########################################
# LOGGING
########################################

def log_text(msg):

    t=time.strftime("%Y-%m-%d %H:%M:%S")

    line=f"[{t}] {msg}"

    print(line)

    with open("results/experiment_log.txt","a") as f:
        f.write(line+"\n")


def valid_combo(detector,treatment):

    if detector is None:
        return treatment=="remove"

    if detector in ["ZScore","Percentile"]:
        return True

    return treatment=="remove"


def experiment_done(dataset,model,detector,treatment):

    path="results/summary.csv"

    if not os.path.exists(path):
        return False

    df=pd.read_csv(path)

    return ((df.dataset==dataset)&
            (df.model==model)&
            (df.detector.astype(str)==str(detector))&
            (df.treatment==treatment)).any()


def log_summary(dataset,model,detector,treatment,res):

    path="results/summary.csv"

    if not os.path.exists(path):

        with open(path,"w") as f:

            f.write(
            "dataset,model,detector,treatment,"
            "mean,std,train_size,"
            "removed,removed_pct,"
            "clipped_values,clipped_rows,clipped_pct,"
            "outlier_pct,time\n"
            )

    with open(path,"a") as f:

        f.write(

        f"{dataset},{model},{detector},{treatment},"

        f"{res['mean']:.6f},"

        f"{res['std']:.6f},"

        f"{res['train_size']},"

        f"{res['removed']:.2f},"

        f"{res['removed_pct']:.6f},"

        f"{res['clipped']:.2f},"

        f"{res['clipped_rows']:.2f},"

        f"{res['clipped_pct']:.6f},"

        f"{res['outlier_pct']:.6f},"

        f"{res['time']:.3f}\n"

        )


########################################
# DATA
########################################

def load_json(path):

    return json.loads(Path(path).read_text())


def load_dataset(dataset):

    base=Path(DATA_PATH)/dataset

    def block(name):

        return {
            x:np.load(
                base/f"{name}_{x}.npy",
                allow_pickle=True
            )
            for x in ["train","val","test"]
        }

    N=block("N") if (base/"N_train.npy").exists() else None

    C=block("C") if (base/"C_train.npy").exists() else None

    y=block("y")

    info=load_json(base/"info.json")

    return N,C,y,info


########################################
# PREPROCESS
########################################

def preprocess_train(X):

    X=pd.DataFrame(X)

    numeric=X.select_dtypes(include=[np.number]).columns

    means={}
    stds={}

    for col in numeric:

        m=X[col].mean()

        X[col]=X[col].fillna(m)

        s=X[col].std()

        if s==0:
            s=1

        X[col]=(X[col]-m)/s

        means[col]=m
        stds[col]=s

    X=X.fillna(0).infer_objects(copy=False)

    return X.values,means,stds


def preprocess_test(X,means,stds):

    X=pd.DataFrame(X)

    for col in means:

        if col in X:

            X[col]=X[col].fillna(means[col])

            X[col]=(X[col]-means[col])/stds[col]

    X=X.fillna(0).infer_objects(copy=False)

    return X.values


########################################
# AUTOENCODER
########################################

class AE(nn.Module):

    def __init__(self,d):

        super().__init__()

        self.encoder=nn.Sequential(

            nn.Linear(d,64),
            nn.ReLU(),
            nn.Linear(64,16)
        )

        self.decoder=nn.Sequential(

            nn.Linear(16,64),
            nn.ReLU(),
            nn.Linear(64,d)
        )

    def forward(self,x):

        return self.decoder(self.encoder(x))


def ae_outliers(X,seed):

    torch.manual_seed(seed)

    X=torch.tensor(X,dtype=torch.float32)

    d=X.shape[1]

    model=AE(d)

    opt=torch.optim.Adam(model.parameters(),lr=0.001)

    loss_fn=nn.MSELoss()

    for _ in range(20):

        out=model(X)

        loss=loss_fn(out,X)

        opt.zero_grad()

        loss.backward()

        opt.step()

    with torch.no_grad():

        recon=model(X)

        err=((X-recon)**2).mean(1).numpy()

    thresh=np.percentile(err,100*(1-CONTAMINATION))

    mask=err<thresh

    return mask,None,None


########################################
# OUTLIERS
########################################

def detect_outliers(X,method,seed):

    X=np.asarray(X)

    if X.dtype==object:

        X=pd.DataFrame(X).apply(
            pd.to_numeric,
            errors="coerce"
        ).values

    X=np.nan_to_num(X)

    X=X.astype(np.float64)

    if method is None:
        return np.ones(len(X),bool),None,None


    if method=="ZScore":

        mean=X.mean(0)

        std=X.std(0)

        std[std==0]=1

        z=np.abs((X-mean)/std)

        mask=(z<3).all(1)

        lower=mean-3*std

        upper=mean+3*std

        return mask,lower,upper


    if method=="Percentile":

        lower=np.percentile(X,LOW_PCTL,axis=0)

        upper=np.percentile(X,HIGH_PCTL,axis=0)

        mask=((X>=lower)&(X<=upper)).all(1)

        return mask,lower,upper


    if method=="IsolationForest":

        clf=IsolationForest(
            contamination=CONTAMINATION,
            random_state=seed,
            n_estimators=200
        )

        mask=clf.fit_predict(X)==1

        return mask,None,None


    if method=="LOF":

        clf=LocalOutlierFactor(
            contamination=CONTAMINATION
        )

        mask=clf.fit_predict(X)==1

        return mask,None,None


    if method=="Autoencoder":

        return ae_outliers(X,seed)


########################################
# CLIP
########################################

def clip_numeric(X,lower,upper):

    if lower is None:
        return X,0,0

    original_X=X.copy()

    clipped_values=0

    for i in range(X.shape[1]):

        before=X[:,i].copy()

        X[:,i]=np.clip(
            X[:,i],
            lower[i],
            upper[i]
        )

        clipped_values+=np.sum(before!=X[:,i])

    clipped_rows=np.sum(
        np.any(original_X!=X,axis=1)
    )

    return X,clipped_values,clipped_rows


########################################
# MODELS
########################################

def make_model(name,task,seed):

    if name=="mlp":

        if task=="classification":

            return MLPClassifier(
                hidden_layer_sizes=(100,),
                max_iter=500,
                random_state=seed
            )

        return MLPRegressor(
            hidden_layer_sizes=(100,),
            max_iter=500,
            random_state=seed
        )


    if name=="xgboost":

        if task=="classification":

            return XGBClassifier(
                eval_metric="logloss",
                random_state=seed,
                n_estimators=200,
                tree_method="hist"
            )

        return XGBRegressor(
            random_state=seed,
            n_estimators=200,
            tree_method="hist"
        )


    if name=="randomforest":

        if task=="classification":

            return RandomForestClassifier(
                n_estimators=200,
                random_state=seed
            )

        return RandomForestRegressor(
            n_estimators=100,
            random_state=seed
        )


########################################
# SINGLE RUN
########################################

def single_run(dataset,model,detector,treatment,seed):

    np.random.seed(seed)
    random.seed(seed)

    N,C,y,info=load_dataset(dataset)

    y_train=y["train"].ravel()
    y_test=y["test"].ravel()

    idx=np.random.choice(len(y_train),len(y_train),replace=True)

    y_train=y_train[idx]

    if N is not None:
        N["train"]=N["train"][idx]

    if C is not None:
        C["train"]=C["train"][idx]

    before=len(y_train)

    if N is not None:

        mask,lower,upper=detect_outliers(
            N["train"],
            detector,
            seed
        )

    else:

        mask=np.ones(before,bool)
        lower=None
        upper=None

    clipped=0
    clipped_rows=0

    if treatment=="remove":

        if N is not None:
            N["train"]=N["train"][mask]

        if C is not None:
            C["train"]=C["train"][mask]

        y_train=y_train[mask]


    if treatment=="clip" and N is not None:

        N["train"],clipped,clipped_rows=clip_numeric(
            N["train"],
            lower,
            upper
        )


    after=len(y_train)

    removed=before-after

    removed_pct=removed/before if before>0 else 0

    clipped_pct=clipped_rows/before if before>0 else 0

    outlier_pct=removed_pct if treatment=="remove" else clipped_pct

    train_size=after


    if N is not None and C is not None:

        X_train=np.hstack([N["train"],C["train"]])
        X_test=np.hstack([N["test"],C["test"]])

    elif N is not None:

        X_train=N["train"]
        X_test=N["test"]

    else:

        X_train=C["train"]
        X_test=C["test"]


    X_train=pd.DataFrame(X_train)
    X_test=pd.DataFrame(X_test)


    for col in X_train.columns:

        if X_train[col].dtype==object:

            le=LabelEncoder()

            X_train[col]=le.fit_transform(
                X_train[col].astype(str)
            )

            X_test[col]=X_test[col].astype(str)

            X_test[col]=X_test[col].map(

                lambda x:
                le.transform([x])[0]
                if x in le.classes_
                else 0
            )


    X_train,means,stds=preprocess_train(X_train)

    X_test=preprocess_test(X_test,means,stds)


    task=info["task_type"]

    if task!="regression":
        task="classification"


    if task=="classification":

        le=LabelEncoder()

        le.fit(y_train)

        y_train=le.transform(y_train)

        y_test=np.array([

            le.transform([x])[0]

            if x in le.classes_

            else 0

            for x in y_test
        ])


    model=make_model(model,task,seed)

    start=time.time()

    model.fit(X_train,y_train)

    train_time=time.time()-start

    score=evaluate(model,X_test,y_test,task)


    return {

        "score":score,

        "removed":removed,
        "removed_pct":removed_pct,

        "clipped":clipped,
        "clipped_rows":clipped_rows,
        "clipped_pct":clipped_pct,

        "outlier_pct":outlier_pct,

        "train_size":train_size,

        "time":train_time
    }


########################################
# EVALUATE
########################################

def evaluate(model,X,y,task):

    pred=model.predict(X)

    if task=="classification":
        return accuracy_score(y,pred)

    return mean_squared_error(y,pred)


########################################
# EXPERIMENT
########################################

def run_experiment(dataset,model,detector,treatment):

    scores=[]
    removed=[]
    removed_pct=[]
    clipped=[]
    clipped_rows=[]
    clipped_pct=[]
    outlier_pct=[]
    times=[]
    train_sizes=[]

    for i in range(RUNS):

        seed=42+i

        r=single_run(dataset,model,detector,treatment,seed)

        scores.append(r["score"])

        removed.append(r["removed"])
        removed_pct.append(r["removed_pct"])

        clipped.append(r["clipped"])
        clipped_rows.append(r["clipped_rows"])
        clipped_pct.append(r["clipped_pct"])

        outlier_pct.append(r["outlier_pct"])

        times.append(r["time"])

        train_sizes.append(r["train_size"])


        log_text(

        f"{dataset} {model} "

        f"{detector} {treatment} "

        f"run={i} "

        f"score={r['score']:.5f} "

        f"outliers={r['outlier_pct']:.4f}"

        )


    scores=np.array(scores)

    return {

        "mean":scores.mean(),

        "std":scores.std(),

        "removed":np.mean(removed),

        "removed_pct":np.mean(removed_pct),

        "clipped":np.mean(clipped),

        "clipped_rows":np.mean(clipped_rows),

        "clipped_pct":np.mean(clipped_pct),

        "outlier_pct":np.mean(outlier_pct),

        "train_size":int(np.mean(train_sizes)),

        "time":np.mean(times)
    }


########################################
# MAIN
########################################

def main():

    os.makedirs("results",exist_ok=True)

    log_text("Experiment started")

    combos=[

        (d,m,o,t)

        for d in DATASETS

        for m in MODELS

        for o in OUTLIERS

        for t in TREATMENTS

        if valid_combo(o,t)
    ]

    total=len(combos)

    counter=0

    for dataset,model,detector,treatment in combos:

        counter+=1

        label=f"{dataset} {model} {detector} {treatment}"

        if experiment_done(dataset,model,detector,treatment):

            log_text(f"SKIP {counter}/{total} {label}")

            continue

        try:

            log_text(f"RUN {counter}/{total} {label}")

            res=run_experiment(

                dataset,
                model,
                detector,
                treatment
            )

            log_text(

            f"RESULT {label} "

            f"{res['mean']:.4f} "

            f"outliers={res['outlier_pct']:.4f}"

            )

            log_summary(
                dataset,
                model,
                detector,
                treatment,
                res
            )

        except Exception as e:

            log_text(f"FAILED {label}")

            log_text(str(e))

            continue


    log_text("Experiment finished")


if __name__=="__main__":

    main()
# Out:
# [2026-03-19 20:13:50] Experiment started
# [2026-03-19 20:13:50] RUN 1/120 cmc mlp None remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:13:51] cmc mlp None remove run=0 score=0.51864 outliers=0.0000
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:13:52] cmc mlp None remove run=1 score=0.51186 outliers=0.0000
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:13:52] cmc mlp None remove run=2 score=0.48136 outliers=0.0000
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:13:53] cmc mlp None remove run=3 score=0.50169 outliers=0.0000
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:13:54] cmc mlp None remove run=4 score=0.51864 outliers=0.0000
# [2026-03-19 20:13:54] RESULT cmc mlp None remove 0.5064 outliers=0.0000
# [2026-03-19 20:13:54] RUN 2/120 cmc mlp ZScore remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:13:55] cmc mlp ZScore remove run=0 score=0.52203 outliers=0.0149
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:13:56] cmc mlp ZScore remove run=1 score=0.52542 outliers=0.0138
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:13:57] cmc mlp ZScore remove run=2 score=0.50847 outliers=0.0170
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:13:59] cmc mlp ZScore remove run=3 score=0.53559 outliers=0.0127
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:00] cmc mlp ZScore remove run=4 score=0.47458 outliers=0.0138
# [2026-03-19 20:14:00] RESULT cmc mlp ZScore remove 0.5132 outliers=0.0144
# [2026-03-19 20:14:00] RUN 3/120 cmc mlp ZScore clip
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:01] cmc mlp ZScore clip run=0 score=0.51864 outliers=0.0149
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:02] cmc mlp ZScore clip run=1 score=0.52881 outliers=0.0138
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:03] cmc mlp ZScore clip run=2 score=0.49153 outliers=0.0170
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:04] cmc mlp ZScore clip run=3 score=0.51525 outliers=0.0127
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:04] cmc mlp ZScore clip run=4 score=0.46441 outliers=0.0138
# [2026-03-19 20:14:04] RESULT cmc mlp ZScore clip 0.5037 outliers=0.0144
# [2026-03-19 20:14:04] RUN 4/120 cmc mlp Percentile remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:05] cmc mlp Percentile remove run=0 score=0.49153 outliers=0.1051
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:06] cmc mlp Percentile remove run=1 score=0.49492 outliers=0.0817
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:07] cmc mlp Percentile remove run=2 score=0.49831 outliers=0.1040
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:08] cmc mlp Percentile remove run=3 score=0.50847 outliers=0.1008
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:08] cmc mlp Percentile remove run=4 score=0.51864 outliers=0.0924
# [2026-03-19 20:14:08] RESULT cmc mlp Percentile remove 0.5024 outliers=0.0968
# [2026-03-19 20:14:08] RUN 5/120 cmc mlp Percentile clip
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:09] cmc mlp Percentile clip run=0 score=0.50169 outliers=0.1051
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:10] cmc mlp Percentile clip run=1 score=0.52203 outliers=0.0817
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:11] cmc mlp Percentile clip run=2 score=0.50508 outliers=0.1040
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:12] cmc mlp Percentile clip run=3 score=0.52203 outliers=0.1008
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:13] cmc mlp Percentile clip run=4 score=0.48475 outliers=0.0924
# [2026-03-19 20:14:13] RESULT cmc mlp Percentile clip 0.5071 outliers=0.0968
# [2026-03-19 20:14:13] RUN 6/120 cmc mlp IsolationForest remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:14] cmc mlp IsolationForest remove run=0 score=0.52203 outliers=0.0510
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:15] cmc mlp IsolationForest remove run=1 score=0.52203 outliers=0.0467
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:16] cmc mlp IsolationForest remove run=2 score=0.51864 outliers=0.0499
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:17] cmc mlp IsolationForest remove run=3 score=0.51864 outliers=0.0510
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:18] cmc mlp IsolationForest remove run=4 score=0.47797 outliers=0.0488
# [2026-03-19 20:14:18] RESULT cmc mlp IsolationForest remove 0.5119 outliers=0.0495
# [2026-03-19 20:14:18] RUN 7/120 cmc mlp LOF remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neighbors/_lof.py:322: UserWarning: Duplicate values are leading to incorrect results. Increase the number of neighbors for more accurate results.
#   warnings.warn(
# [2026-03-19 20:14:19] cmc mlp LOF remove run=0 score=0.50847 outliers=0.0510
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:19] cmc mlp LOF remove run=1 score=0.51864 outliers=0.0499
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:20] cmc mlp LOF remove run=2 score=0.48136 outliers=0.0488
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:21] cmc mlp LOF remove run=3 score=0.51525 outliers=0.0510
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:22] cmc mlp LOF remove run=4 score=0.48475 outliers=0.0510
# [2026-03-19 20:14:22] RESULT cmc mlp LOF remove 0.5017 outliers=0.0503
# [2026-03-19 20:14:22] RUN 8/120 cmc mlp Autoencoder remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:23] cmc mlp Autoencoder remove run=0 score=0.49153 outliers=0.0541
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:23] cmc mlp Autoencoder remove run=1 score=0.49831 outliers=0.0531
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:24] cmc mlp Autoencoder remove run=2 score=0.48475 outliers=0.0552
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:25] cmc mlp Autoencoder remove run=3 score=0.49153 outliers=0.0552
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-19 20:14:26] cmc mlp Autoencoder remove run=4 score=0.52203 outliers=0.0531
# [2026-03-19 20:14:26] RESULT cmc mlp Autoencoder remove 0.4976 outliers=0.0541
# [2026-03-19 20:14:26] RUN 9/120 cmc xgboost None remove
# [2026-03-19 20:14:26] cmc xgboost None remove run=0 score=0.55254 outliers=0.0000
# [2026-03-19 20:14:26] cmc xgboost None remove run=1 score=0.51186 outliers=0.0000
# [2026-03-19 20:14:27] cmc xgboost None remove run=2 score=0.50847 outliers=0.0000
# [2026-03-19 20:14:27] cmc xgboost None remove run=3 score=0.49492 outliers=0.0000
# [2026-03-19 20:14:27] cmc xgboost None remove run=4 score=0.51525 outliers=0.0000
# [2026-03-19 20:14:27] RESULT cmc xgboost None remove 0.5166 outliers=0.0000
# [2026-03-19 20:14:27] RUN 10/120 cmc xgboost ZScore remove
# [2026-03-19 20:14:27] cmc xgboost ZScore remove run=0 score=0.53559 outliers=0.0149
# [2026-03-19 20:14:27] cmc xgboost ZScore remove run=1 score=0.48814 outliers=0.0138
# [2026-03-19 20:14:28] cmc xgboost ZScore remove run=2 score=0.49153 outliers=0.0170
# [2026-03-19 20:14:28] cmc xgboost ZScore remove run=3 score=0.48475 outliers=0.0127
# [2026-03-19 20:14:28] cmc xgboost ZScore remove run=4 score=0.50847 outliers=0.0138
# [2026-03-19 20:14:28] RESULT cmc xgboost ZScore remove 0.5017 outliers=0.0144
# [2026-03-19 20:14:28] RUN 11/120 cmc xgboost ZScore clip
# [2026-03-19 20:14:28] cmc xgboost ZScore clip run=0 score=0.54915 outliers=0.0149
# [2026-03-19 20:14:29] cmc xgboost ZScore clip run=1 score=0.48814 outliers=0.0138
# [2026-03-19 20:14:29] cmc xgboost ZScore clip run=2 score=0.51186 outliers=0.0170
# [2026-03-19 20:14:29] cmc xgboost ZScore clip run=3 score=0.50169 outliers=0.0127
# [2026-03-19 20:14:29] cmc xgboost ZScore clip run=4 score=0.51186 outliers=0.0138
# [2026-03-19 20:14:29] RESULT cmc xgboost ZScore clip 0.5125 outliers=0.0144
# [2026-03-19 20:14:29] RUN 12/120 cmc xgboost Percentile remove
# [2026-03-19 20:14:29] cmc xgboost Percentile remove run=0 score=0.49492 outliers=0.1051
# [2026-03-19 20:14:30] cmc xgboost Percentile remove run=1 score=0.46441 outliers=0.0817
# [2026-03-19 20:14:30] cmc xgboost Percentile remove run=2 score=0.48814 outliers=0.1040
# [2026-03-19 20:14:30] cmc xgboost Percentile remove run=3 score=0.48475 outliers=0.1008
# [2026-03-19 20:14:30] cmc xgboost Percentile remove run=4 score=0.51525 outliers=0.0924
# [2026-03-19 20:14:30] RESULT cmc xgboost Percentile remove 0.4895 outliers=0.0968
# [2026-03-19 20:14:30] RUN 13/120 cmc xgboost Percentile clip
# [2026-03-19 20:14:30] cmc xgboost Percentile clip run=0 score=0.51186 outliers=0.1051
# [2026-03-19 20:14:31] cmc xgboost Percentile clip run=1 score=0.50169 outliers=0.0817
# [2026-03-19 20:14:31] cmc xgboost Percentile clip run=2 score=0.49831 outliers=0.1040
# [2026-03-19 20:14:31] cmc xgboost Percentile clip run=3 score=0.49492 outliers=0.1008
# [2026-03-19 20:14:31] cmc xgboost Percentile clip run=4 score=0.49492 outliers=0.0924
# [2026-03-19 20:14:31] RESULT cmc xgboost Percentile clip 0.5003 outliers=0.0968
# [2026-03-19 20:14:31] RUN 14/120 cmc xgboost IsolationForest remove
# [2026-03-19 20:14:34] cmc xgboost IsolationForest remove run=0 score=0.53220 outliers=0.0510
# [2026-03-19 20:14:34] cmc xgboost IsolationForest remove run=1 score=0.49153 outliers=0.0467
# [2026-03-19 20:14:34] cmc xgboost IsolationForest remove run=2 score=0.51864 outliers=0.0499
# [2026-03-19 20:14:35] cmc xgboost IsolationForest remove run=3 score=0.48475 outliers=0.0510
# [2026-03-19 20:14:35] cmc xgboost IsolationForest remove run=4 score=0.51525 outliers=0.0488
# [2026-03-19 20:14:35] RESULT cmc xgboost IsolationForest remove 0.5085 outliers=0.0495
# [2026-03-19 20:14:35] RUN 15/120 cmc xgboost LOF remove
# [2026-03-19 20:14:35] cmc xgboost LOF remove run=0 score=0.52542 outliers=0.0510
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neighbors/_lof.py:322: UserWarning: Duplicate values are leading to incorrect results. Increase the number of neighbors for more accurate results.
#   warnings.warn(
# [2026-03-19 20:14:36] cmc xgboost LOF remove run=1 score=0.50508 outliers=0.0499
# [2026-03-19 20:14:36] cmc xgboost LOF remove run=2 score=0.50169 outliers=0.0488
# [2026-03-19 20:14:36] cmc xgboost LOF remove run=3 score=0.47458 outliers=0.0510
# [2026-03-19 20:14:36] cmc xgboost LOF remove run=4 score=0.50508 outliers=0.0510
# [2026-03-19 20:14:36] RESULT cmc xgboost LOF remove 0.5024 outliers=0.0503
# [2026-03-19 20:14:36] RUN 16/120 cmc xgboost Autoencoder remove
# [2026-03-19 20:14:37] cmc xgboost Autoencoder remove run=0 score=0.51864 outliers=0.0541
# [2026-03-19 20:14:37] cmc xgboost Autoencoder remove run=1 score=0.49831 outliers=0.0531
# [2026-03-19 20:14:37] cmc xgboost Autoencoder remove run=2 score=0.50508 outliers=0.0552
# [2026-03-19 20:14:37] cmc xgboost Autoencoder remove run=3 score=0.47797 outliers=0.0552
# [2026-03-19 20:14:37] cmc xgboost Autoencoder remove run=4 score=0.49831 outliers=0.0531
# [2026-03-19 20:14:37] RESULT cmc xgboost Autoencoder remove 0.4997 outliers=0.0541
# [2026-03-19 20:14:37] RUN 17/120 cmc randomforest None remove
# [2026-03-19 20:14:38] cmc randomforest None remove run=0 score=0.53220 outliers=0.0000
# [2026-03-19 20:14:38] cmc randomforest None remove run=1 score=0.51186 outliers=0.0000
# [2026-03-19 20:14:38] cmc randomforest None remove run=2 score=0.50508 outliers=0.0000
# [2026-03-19 20:14:39] cmc randomforest None remove run=3 score=0.50847 outliers=0.0000
# [2026-03-19 20:14:39] cmc randomforest None remove run=4 score=0.53220 outliers=0.0000
# [2026-03-19 20:14:39] RESULT cmc randomforest None remove 0.5180 outliers=0.0000
# [2026-03-19 20:14:39] RUN 18/120 cmc randomforest ZScore remove
# [2026-03-19 20:14:39] cmc randomforest ZScore remove run=0 score=0.52203 outliers=0.0149
# [2026-03-19 20:14:40] cmc randomforest ZScore remove run=1 score=0.51525 outliers=0.0138
# [2026-03-19 20:14:40] cmc randomforest ZScore remove run=2 score=0.50847 outliers=0.0170
# [2026-03-19 20:14:40] cmc randomforest ZScore remove run=3 score=0.48814 outliers=0.0127
# [2026-03-19 20:14:41] cmc randomforest ZScore remove run=4 score=0.51525 outliers=0.0138
# [2026-03-19 20:14:41] RESULT cmc randomforest ZScore remove 0.5098 outliers=0.0144
# [2026-03-19 20:14:41] RUN 19/120 cmc randomforest ZScore clip
# [2026-03-19 20:14:41] cmc randomforest ZScore clip run=0 score=0.54237 outliers=0.0149
# [2026-03-19 20:14:41] cmc randomforest ZScore clip run=1 score=0.50169 outliers=0.0138
# [2026-03-19 20:14:42] cmc randomforest ZScore clip run=2 score=0.50847 outliers=0.0170
# [2026-03-19 20:14:42] cmc randomforest ZScore clip run=3 score=0.51186 outliers=0.0127
# [2026-03-19 20:14:42] cmc randomforest ZScore clip run=4 score=0.52881 outliers=0.0138
# [2026-03-19 20:14:42] RESULT cmc randomforest ZScore clip 0.5186 outliers=0.0144
# [2026-03-19 20:14:42] RUN 20/120 cmc randomforest Percentile remove
# [2026-03-19 20:14:43] cmc randomforest Percentile remove run=0 score=0.48814 outliers=0.1051
# [2026-03-19 20:14:43] cmc randomforest Percentile remove run=1 score=0.44746 outliers=0.0817
# [2026-03-19 20:14:43] cmc randomforest Percentile remove run=2 score=0.48136 outliers=0.1040
# [2026-03-19 20:14:43] cmc randomforest Percentile remove run=3 score=0.49153 outliers=0.1008
# [2026-03-19 20:14:44] cmc randomforest Percentile remove run=4 score=0.51525 outliers=0.0924
# [2026-03-19 20:14:44] RESULT cmc randomforest Percentile remove 0.4847 outliers=0.0968
# [2026-03-19 20:14:44] RUN 21/120 cmc randomforest Percentile clip
# [2026-03-19 20:14:44] cmc randomforest Percentile clip run=0 score=0.49831 outliers=0.1051
# [2026-03-19 20:14:44] cmc randomforest Percentile clip run=1 score=0.50169 outliers=0.0817
# [2026-03-19 20:14:45] cmc randomforest Percentile clip run=2 score=0.47797 outliers=0.1040
# [2026-03-19 20:14:45] cmc randomforest Percentile clip run=3 score=0.50169 outliers=0.1008
# [2026-03-19 20:14:45] cmc randomforest Percentile clip run=4 score=0.51525 outliers=0.0924
# [2026-03-19 20:14:45] RESULT cmc randomforest Percentile clip 0.4990 outliers=0.0968
# [2026-03-19 20:14:45] RUN 22/120 cmc randomforest IsolationForest remove
# [2026-03-19 20:14:46] cmc randomforest IsolationForest remove run=0 score=0.50847 outliers=0.0510
# [2026-03-19 20:14:46] cmc randomforest IsolationForest remove run=1 score=0.48136 outliers=0.0467
# [2026-03-19 20:14:47] cmc randomforest IsolationForest remove run=2 score=0.51864 outliers=0.0499
# [2026-03-19 20:14:47] cmc randomforest IsolationForest remove run=3 score=0.49831 outliers=0.0510
# [2026-03-19 20:14:48] cmc randomforest IsolationForest remove run=4 score=0.51525 outliers=0.0488
# [2026-03-19 20:14:48] RESULT cmc randomforest IsolationForest remove 0.5044 outliers=0.0495
# [2026-03-19 20:14:48] RUN 23/120 cmc randomforest LOF remove
# [2026-03-19 20:14:48] cmc randomforest LOF remove run=0 score=0.51186 outliers=0.0510
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neighbors/_lof.py:322: UserWarning: Duplicate values are leading to incorrect results. Increase the number of neighbors for more accurate results.
#   warnings.warn(
# [2026-03-19 20:14:49] cmc randomforest LOF remove run=1 score=0.52542 outliers=0.0499
# [2026-03-19 20:14:49] cmc randomforest LOF remove run=2 score=0.50169 outliers=0.0488
# [2026-03-19 20:14:49] cmc randomforest LOF remove run=3 score=0.48814 outliers=0.0510
# [2026-03-19 20:14:50] cmc randomforest LOF remove run=4 score=0.53559 outliers=0.0510
# [2026-03-19 20:14:50] RESULT cmc randomforest LOF remove 0.5125 outliers=0.0503
# [2026-03-19 20:14:50] RUN 24/120 cmc randomforest Autoencoder remove
# [2026-03-19 20:14:50] cmc randomforest Autoencoder remove run=0 score=0.49153 outliers=0.0541
# [2026-03-19 20:14:50] cmc randomforest Autoencoder remove run=1 score=0.48814 outliers=0.0531
# [2026-03-19 20:14:51] cmc randomforest Autoencoder remove run=2 score=0.50508 outliers=0.0552
# [2026-03-19 20:14:51] cmc randomforest Autoencoder remove run=3 score=0.47797 outliers=0.0552
# [2026-03-19 20:14:51] cmc randomforest Autoencoder remove run=4 score=0.51186 outliers=0.0531
# [2026-03-19 20:14:51] RESULT cmc randomforest Autoencoder remove 0.4949 outliers=0.0541
# [2026-03-19 20:14:51] RUN 25/120 connect-4 mlp None remove
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 835
#     830     log_text("Experiment finished")
#     833 if __name__=="__main__":
# --> 835     main()
#
# Cell In[8], line 795, in main()
#     791 try:
#     793     log_text(f"RUN {counter}/{total} {label}")
# --> 795     res=run_experiment(
#     796
#     797         dataset,
#     798         model,
#     799         detector,
#     800         treatment
#     801     )
#     803     log_text(
#     804
#     805     f"RESULT {label} "
#    (...)    810
#     811     )
#     813     log_summary(
#     814         dataset,
#     815         model,
#    (...)    818         res
#     819     )
#
# Cell In[8], line 691, in run_experiment(dataset, model, detector, treatment)
#     687 for i in range(RUNS):
#     689     seed=42+i
# --> 691     r=single_run(dataset,model,detector,treatment,seed)
#     693     scores.append(r["score"])
#     695     removed.append(r["removed"])
#
# Cell In[8], line 587, in single_run(dataset, model, detector, treatment, seed)
#     581         X_train[col]=le.fit_transform(
#     582             X_train[col].astype(str)
#     583         )
#     585         X_test[col]=X_test[col].astype(str)
# --> 587         X_test[col]=X_test[col].map(
#     588
#     589             lambda x:
#     590             le.transform([x])[0]
#     591             if x in le.classes_
#     592             else 0
#     593         )
#     596 X_train,means,stds=preprocess_train(X_train)
#     598 X_test=preprocess_test(X_test,means,stds)
#
# File ~/code/tabular-nns/env/lib/python3.12/site-packages/pandas/core/series.py:4719, in Series.map(self, arg, na_action)
#    4639 def map(
#    4640     self,
#    4641     arg: Callable | Mapping | Series,
#    4642     na_action: Literal["ignore"] | None = None,
#    4643 ) -> Series:
#    4644     """
#    4645     Map values of Series according to an input mapping or function.
#    4646
#    (...)   4717     dtype: object
#    4718     """
# -> 4719     new_values = self._map_values(arg, na_action=na_action)
#    4720     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4721         self, method="map"
#    4722     )
#
# File ~/code/tabular-nns/env/lib/python3.12/site-packages/pandas/core/base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/code/tabular-nns/env/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[8], line 590, in single_run.<locals>.<lambda>(x)
#     581         X_train[col]=le.fit_transform(
#     582             X_train[col].astype(str)
#     583         )
#     585         X_test[col]=X_test[col].astype(str)
#     587         X_test[col]=X_test[col].map(
#     588
#     589             lambda x:
# --> 590             le.transform([x])[0]
#     591             if x in le.classes_
#     592             else 0
#     593         )
#     596 X_train,means,stds=preprocess_train(X_train)
#     598 X_test=preprocess_test(X_test,means,stds)
#
# File ~/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:129, in LabelEncoder.transform(self, y)
#     127 check_is_fitted(self)
#     128 xp, _ = get_namespace(y)
# --> 129 y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
#     130 # transform of empty array is empty array
#     131 if _num_samples(y) == 0:
#
# File ~/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/utils/validation.py:1454, in column_or_1d(y, dtype, warn, device)
#    1416 """Ravel column or 1d numpy array, else raises an error.
#    1417
#    1418 Parameters
#    (...)   1451 array([1, 1])
#    1452 """
#    1453 xp, _ = get_namespace(y)
# -> 1454 y = check_array(
#    1455     y,
#    1456     ensure_2d=False,
#    1457     dtype=dtype,
#    1458     input_name="y",
#    1459     ensure_all_finite=False,
#    1460     ensure_min_samples=0,
#    1461 )
#    1463 shape = y.shape
#    1464 if len(shape) == 1:
#
# File ~/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/utils/validation.py:1037, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1035 with warnings.catch_warnings():
#    1036     try:
# -> 1037         warnings.simplefilter("error", ComplexWarning)
#    1038         if dtype is not None and xp.isdtype(dtype, "integral"):
#    1039             # Conversion float -> int should not contain NaN or
#    1040             # inf (numpy#14412). We cannot use casting='safe' because
#    1041             # then conversion float -> int would be disallowed.
#    1042             array = _asarray_with_order(array, order=order, xp=xp)
#
# File /usr/lib/python3.12/warnings.py:180, in simplefilter(action, category, lineno, append)
#     176 assert action in ("error", "ignore", "always", "default", "module",
#     177                   "once"), "invalid action: %r" % (action,)
#     178 assert isinstance(lineno, int) and lineno >= 0, \
#     179        "lineno must be an int >= 0"
# --> 180 _add_filter(action, None, category, None, lineno, append=append)
#
# File /usr/lib/python3.12/warnings.py:189, in _add_filter(append, *item)
#     187         filters.remove(item)
#     188     except ValueError:
# --> 189         pass
#     190     filters.insert(0, item)
#     191 else:
#
# KeyboardInterrupt:
# Traceback (most recent call last):
# Exception ignored in: 'zmq.backend.cython._zmq.Frame.__dealloc__'
# Traceback (most recent call last):
#   File "zmq/backend/cython/_zmq.py", line 179, in zmq.backend.cython._zmq._check_rc
#   File "zmq/backend/cython/_zmq.py", line 179, in zmq.backend.cython._zmq._check_rc
#     PyErr_CheckSignals()
#     ^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt:

# %%
res = run_experiment(
    dataset="electricity",
    model="xgboost",
    outlier=None
)

print("\nRESULT:")
print("Mean:", res["mean"])
print("Std:", res["std"])
print("All runs:", res["all"])
# Out:
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:51] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# RESULT:
# Mean: 0.7837360697340836
# Std: 0.0
# All runs: [0.7837360697340836, 0.7837360697340836, 0.7837360697340836, 0.7837360697340836, 0.7837360697340836]

# %%
run_experiment("cmc","mlp",None)
# Out:
# {'mean': np.float64(0.5850847457627119),
#  'std': np.float64(0.007906375450637698),
#  'min': np.float64(0.576271186440678),
#  'max': np.float64(0.5966101694915255),
#  'removed_mean': np.float64(0.0),
#  'time_mean': np.float64(0.26859517097473146),
#  'all': [0.576271186440678,
#   0.5864406779661017,
#   0.5966101694915255,
#   0.5898305084745763,
#   0.576271186440678]}

# %%
run_experiment("eucalyptus","xgboost",None)
run_experiment("eucalyptus","xgboost","ZScore")
# Out:
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:26] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:27] eucalyptus xgboost None run=0 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:27] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:29] eucalyptus xgboost None run=1 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:29] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:30] eucalyptus xgboost None run=2 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:30] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:31] eucalyptus xgboost None run=3 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:32] eucalyptus xgboost None run=4 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:32] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:33] eucalyptus xgboost ZScore run=0 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:33] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:33] eucalyptus xgboost ZScore run=1 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:33] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:34] eucalyptus xgboost ZScore run=2 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:34] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:35] eucalyptus xgboost ZScore run=3 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:35] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:36] eucalyptus xgboost ZScore run=4 score=0.24324 removed=0 (0.000)
# {'mean': np.float64(0.24324324324324326),
#  'std': np.float64(0.0),
#  'min': np.float64(0.24324324324324326),
#  'max': np.float64(0.24324324324324326),
#  'train_size': 470,
#  'removed_mean': np.float64(0.0),
#  'removed_pct': np.float64(0.0),
#  'time_mean': np.float64(0.6785444736480712),
#  'all': [0.24324324324324326,
#   0.24324324324324326,
#   0.24324324324324326,
#   0.24324324324324326,
#   0.24324324324324326]}

# %%
# !pip install torch
# !pip install scikit-learn
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.
