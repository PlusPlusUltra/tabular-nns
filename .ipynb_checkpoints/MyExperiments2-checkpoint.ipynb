# %%
#!/usr/bin/env python3

import os
import json
import time
import random
import numpy as np
import pandas as pd

from pathlib import Path

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, mean_squared_error

from sklearn.ensemble import IsolationForest
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

from sklearn.svm import OneClassSVM

from sklearn.linear_model import LogisticRegression, LinearRegression

from sklearn.neural_network import MLPClassifier, MLPRegressor

from xgboost import XGBClassifier, XGBRegressor


########################################
# CONFIG
########################################

DATA_PATH="data"

DATASETS=[
"Bank_Customer_Churn_Dataset",
"cmc",
"connect-4",
"credit-g",
"electricity",
"elevators",
"eucalyptus",
"eye_movements",
"house_16H",
"kc1",
"phoneme",
"pol",
"socmob",
"splice",
"vehicle"
]

MODELS=[
"mlp",
"xgboost",
"randomforest"
]

OUTLIERS=[
None,
"ZScore",
"IsolationForest",
"IQR"
]

RUNS=5


########################################
# LOGGING
########################################

def log_text(message):

    timestamp=time.strftime("%Y-%m-%d %H:%M:%S")

    line=f"[{timestamp}] {message}"

    print(line)

    with open("results/experiment_log.txt","a") as f:
        f.write(line+"\n")


def experiment_done(dataset,model,outlier):

    path="results/summary.csv"

    if not os.path.exists(path):
        return False

    df=pd.read_csv(path)

    return ((df.dataset==dataset)&
            (df.model==model)&
            (df.outlier.astype(str)==str(outlier))).any()


########################################
# DATA LOADING
########################################

def load_json(path):

    return json.loads(Path(path).read_text())


def load_dataset(dataset):

    base=Path(DATA_PATH)/dataset

    def load_block(name):

        return {
            x:np.load(
                base/f"{name}_{x}.npy",
                allow_pickle=True
            )
            for x in ["train","val","test"]
        }

    N=load_block("N") if (base/"N_train.npy").exists() else None

    C=load_block("C") if (base/"C_train.npy").exists() else None

    y=load_block("y")

    info=load_json(base/"info.json")

    return N,C,y,info


########################################
# PREPROCESSING
########################################

def preprocess_train(X):

    X=pd.DataFrame(X)

    numeric_cols=X.select_dtypes(include=[np.number]).columns

    means={}
    stds={}

    for col in numeric_cols:

        mean=X[col].mean()

        X[col]=X[col].fillna(mean)

        std=X[col].std()

        if std==0:
            std=1

        X[col]=(X[col]-mean)/std

        means[col]=mean
        stds[col]=std

    X=X.fillna(0).infer_objects(copy=False)

    return X.values,means,stds


def preprocess_test(X,means,stds):

    X=pd.DataFrame(X)

    for col in means:

        if col in X:

            X[col]=X[col].fillna(means[col])

            X[col]=(X[col]-means[col])/stds[col]

    X=X.fillna(0).infer_objects(copy=False)

    return X.values


########################################
# OUTLIERS
########################################

def detect_outliers(X,method,seed):

    X=np.asarray(X)

    if X.dtype==object:

        X=pd.DataFrame(X).apply(
            pd.to_numeric,
            errors="coerce"
        ).values

    X=np.nan_to_num(X)

    X=X.astype(np.float64)

    CONTAMINATION=0.05

    if method is None:
        return np.ones(len(X),dtype=bool)

    if method=="ZScore":

        mean=X.mean(0)

        std=X.std(0)

        std[std==0]=1

        z=np.abs((X-mean)/std)

        return (z<3).all(1)


    if method=="IQR":

        Q1=np.percentile(X,25,axis=0)

        Q3=np.percentile(X,75,axis=0)

        IQR=Q3-Q1

        lower=Q1-1.5*IQR

        upper=Q3+1.5*IQR

        return ((X>=lower)&
                (X<=upper)).all(1)


    if method=="IsolationForest":

        clf=IsolationForest(

            n_estimators=200,

            contamination=CONTAMINATION,

            random_state=seed
        )

        return clf.fit_predict(X)==1


    if method=="OneClassSVM":

        clf=OneClassSVM(

            nu=CONTAMINATION,

            kernel="rbf",

            gamma="scale"
        )

        return clf.fit_predict(X)==1


    raise ValueError("Unknown method")


########################################
# MODELS
########################################

def make_model(name,task,seed):

    name=name.lower()

    if name=="mlp":

        if task=="classification":

            return MLPClassifier(

                hidden_layer_sizes=(100,),
                max_iter=500,
                random_state=seed,
                shuffle=True,
                alpha=0.0001,
                learning_rate_init=0.001
            )

        return MLPRegressor(

            hidden_layer_sizes=(100,),
            max_iter=500,
            random_state=seed
        )


    if name=="xgboost":

        if task=="classification":

            return XGBClassifier(

                use_label_encoder=False,
                eval_metric="logloss",
                random_state=seed,
                subsample=0.9,
                colsample_bytree=0.9,
                n_estimators=200,
                learning_rate=0.1,
                tree_method="hist"
            )

        return XGBRegressor(

            random_state=seed,
            subsample=0.9,
            colsample_bytree=0.9,
            n_estimators=200,
            tree_method="hist"
        )


    if name=="randomforest":

        if task=="classification":

            return RandomForestClassifier(

                n_estimators=200,
                random_state=seed,
                max_features="sqrt",
                bootstrap=True
            )

        return RandomForestRegressor(

            n_estimators=100,
            random_state=seed
        )


    if name=="linear":

        if task=="classification":

            return LogisticRegression(max_iter=1000)

        return LinearRegression()


    raise ValueError("Unknown model")


########################################
# SINGLE RUN
########################################

def single_run(dataset,model,outlier,seed):

    np.random.seed(seed)
    random.seed(seed)

    N,C,y,info=load_dataset(dataset)

    # split numeric/categorical consistently
    if N is not None:

        train_df=pd.DataFrame(N["train"])
        test_df=pd.DataFrame(N["test"])

        numeric_cols=train_df.select_dtypes(include=[np.number]).columns

        if len(numeric_cols)!=train_df.shape[1]:

            N["train"]=train_df[numeric_cols].values
            N["test"]=test_df[numeric_cols].values

            cat_train=train_df.drop(columns=numeric_cols).values
            cat_test=test_df.drop(columns=numeric_cols).values

            if C is None:

                C={}
                C["train"]=cat_train
                C["test"]=cat_test

            else:

                C["train"]=np.hstack([C["train"],cat_train])
                C["test"]=np.hstack([C["test"],cat_test])


    y_train=y["train"].ravel()
    y_test=y["test"].ravel()


    # bootstrap
    idx=np.random.choice(

        len(y_train),

        size=len(y_train),

        replace=True
    )

    y_train=y_train[idx]

    if N is not None:
        N["train"]=N["train"][idx]

    if C is not None:
        C["train"]=C["train"][idx]


    if N is not None:
        before=len(N["train"])
        mask=detect_outliers(N["train"],outlier,seed)

    else:
        before=len(C["train"])
        mask=np.ones(before,dtype=bool)


    if N is not None:
        N["train"]=N["train"][mask]

    if C is not None:
        C["train"]=C["train"][mask]

    y_train=y_train[mask]

    after=len(y_train)

    removed=before-after


    if C is not None:

        X_train=np.hstack([N["train"],C["train"]])

        X_test=np.hstack([N["test"],C["test"]])

    else:

        X_train=N["train"]
        X_test=N["test"]


    X_train=pd.DataFrame(X_train)
    X_test=pd.DataFrame(X_test)


    for col in X_train.columns:

        if X_train[col].dtype==object:

            le=LabelEncoder()

            X_train[col]=le.fit_transform(X_train[col].astype(str))

            X_test[col]=X_test[col].astype(str)

            X_test[col]=X_test[col].map(

                lambda x:
                le.transform([x])[0]
                if x in le.classes_
                else 0
            )


    X_train,means,stds=preprocess_train(X_train)

    X_test=preprocess_test(X_test,means,stds)


    perm=np.random.permutation(len(X_train))

    X_train=X_train[perm]
    y_train=y_train[perm]


    task=info["task_type"]

    if task!="regression":
        task="classification"


    if task=="classification":

        le=LabelEncoder()

        le.fit(y_train)

        y_train=le.transform(y_train)

        y_test=np.array([

            le.transform([x])[0]

            if x in le.classes_

            else 0

            for x in y_test
        ])


    model=make_model(model,task,seed)

    start=time.time()

    model.fit(X_train,y_train)

    train_time=time.time()-start


    score=evaluate(

        model,

        X_test,

        y_test,

        task
    )


    return {

        "score":score,

        "train_before":before,

        "train_after":after,

        "removed":removed,

        "removed_pct":removed/before if before>0 else 0,

        "time":train_time
    }


########################################
# EVALUATION
########################################

def evaluate(model,X,y,task):

    pred=model.predict(X)

    if task=="classification":
        return accuracy_score(y,pred)

    return mean_squared_error(y,pred)


########################################
# EXPERIMENT LOOP
########################################

def run_experiment(dataset,model,outlier):

    scores=[]
    removed=[]
    removed_pct=[]
    times=[]
    train_sizes=[]

    for i in range(RUNS):

        seed=42+i

        result=single_run(

            dataset,
            model,
            outlier,
            seed
        )

        scores.append(result["score"])
        removed.append(result["removed"])
        removed_pct.append(result["removed_pct"])
        times.append(result["time"])
        train_sizes.append(result["train_before"])


        log_text(

        f"{dataset} {model} {outlier} "

        f"run={i} "

        f"score={result['score']:.5f} "

        f"removed={result['removed']} "

        f"({result['removed_pct']:.3f})"
        )


    scores=np.array(scores)

    return {

        "mean":scores.mean(),
        "std":scores.std(),
        "min":scores.min(),
        "max":scores.max(),
        "train_size":int(np.mean(train_sizes)),
        "removed_mean":np.mean(removed),
        "removed_pct":np.mean(removed_pct),
        "time_mean":np.mean(times),
        "all":scores.tolist()
    }


########################################
# LOGGING
########################################

def init_logs():

    os.makedirs("results",exist_ok=True)

    if not os.path.exists("results/summary.csv"):

        with open("results/summary.csv","w") as f:

            f.write(

            "dataset,model,outlier,mean,std,min,max,train_size,removed,removed_pct,time\n"
            )

    if not os.path.exists("results/runs.csv"):

        with open("results/runs.csv","w") as f:

            f.write(

            "dataset,model,outlier,run,seed,score\n"
            )

    with open("results/experiment_log.txt","a") as f:

        f.write("\n====================\n")

        f.write(

        "START "+time.strftime("%Y-%m-%d %H:%M:%S")+"\n"
        )


def log_summary(dataset,model,outlier,res):

    with open("results/summary.csv","a") as f:

        f.write(

        f"{dataset},{model},{outlier},"

        f"{res['mean']:.5f},"

        f"{res['std']:.5f},"

        f"{res['min']:.5f},"

        f"{res['max']:.5f},"

        f"{res['train_size']},"

        f"{res['removed_mean']:.2f},"

        f"{res['removed_pct']:.4f},"

        f"{res['time_mean']:.3f}\n"
        )


def log_runs(dataset,model,outlier,res):

    with open("results/runs.csv","a") as f:

        for i,score in enumerate(res["all"]):

            seed=42+i

            f.write(

            f"{dataset},{model},{outlier},{i},{seed},{score:.5f}\n"
            )


########################################
# MAIN
########################################

def main():

    init_logs()

    log_text("Experiment started")

    total=len(DATASETS)*len(MODELS)*len(OUTLIERS)

    total_runs=total*RUNS

    log_text("===== EXPERIMENT SETUP =====")

    log_text(f"Datasets: {DATASETS}")
    log_text(f"Models: {MODELS}")
    log_text(f"Outliers: {OUTLIERS}")
    log_text(f"Runs per experiment: {RUNS}")

    log_text(f"Total experiments: {total}")
    log_text(f"Total model trainings: {total_runs}")

    log_text("============================")


    counter=0

    for dataset in DATASETS:

        log_text(f"==== DATASET {dataset} ====")

        try:

            load_dataset(dataset)

        except Exception as e:

            log_text(f"DATASET FAILED {dataset}")
            log_text(str(e))

            continue


        for model in MODELS:

            for outlier in OUTLIERS:

                counter+=1

                progress=100*counter/total

                label=f"{dataset} {model} {outlier}"


                if experiment_done(dataset,model,outlier):

                    log_text(

                    f"SKIP {counter}/{total} "

                    f"({progress:.1f}%) "

                    f"{label}"
                    )

                    continue


                try:

                    log_text(

                    f"RUN {counter}/{total} "

                    f"({progress:.1f}%) "

                    f"{label}"
                    )


                    res=run_experiment(

                        dataset,
                        model,
                        outlier
                    )


                    log_text(

                    f"RESULT {label} "

                    f"mean={res['mean']:.5f} "

                    f"std={res['std']:.5f} "

                    f"removed={res['removed_mean']:.1f} "

                    f"({res['removed_pct']:.3f})"
                    )


                    log_summary(

                        dataset,
                        model,
                        outlier,
                        res
                    )


                    log_runs(

                        dataset,
                        model,
                        outlier,
                        res
                    )


                except Exception as e:

                    log_text(f"EXPERIMENT FAILED {label}")
                    log_text(str(e))

                    continue


        log_text(f"==== DATASET {dataset} DONE ====")


    log_text("Experiment finished")


if __name__=="__main__":

    main()
# Out:
# [2026-03-19 15:32:19] Experiment started
# [2026-03-19 15:32:19] ===== EXPERIMENT SETUP =====
# [2026-03-19 15:32:19] Datasets: ['Bank_Customer_Churn_Dataset', 'cmc', 'connect-4', 'credit-g', 'electricity', 'elevators', 'eucalyptus', 'eye_movements', 'house_16H', 'kc1', 'phoneme', 'pol', 'socmob', 'splice', 'vehicle']
# [2026-03-19 15:32:19] Models: ['mlp', 'xgboost', 'randomforest']
# [2026-03-19 15:32:19] Outliers: [None, 'ZScore', 'IsolationForest', 'IQR']
# [2026-03-19 15:32:19] Runs per experiment: 5
# [2026-03-19 15:32:19] Total experiments: 180
# [2026-03-19 15:32:19] Total model trainings: 900
# [2026-03-19 15:32:19] ============================
# [2026-03-19 15:32:19] ==== DATASET Bank_Customer_Churn_Dataset ====
# [2026-03-19 15:32:19] RUN 1/180 (0.6%) Bank_Customer_Churn_Dataset mlp None
# [2026-03-19 15:32:22] EXPERIMENT FAILED Bank_Customer_Churn_Dataset mlp None
# [2026-03-19 15:32:22] Classification metrics can't handle a mix of binary and continuous targets
# [2026-03-19 15:32:22] RUN 2/180 (1.1%) Bank_Customer_Churn_Dataset mlp ZScore
# [2026-03-19 15:32:26] EXPERIMENT FAILED Bank_Customer_Churn_Dataset mlp ZScore
# [2026-03-19 15:32:26] Classification metrics can't handle a mix of binary and continuous targets
# [2026-03-19 15:32:26] RUN 3/180 (1.7%) Bank_Customer_Churn_Dataset mlp IsolationForest
# [2026-03-19 15:32:30] EXPERIMENT FAILED Bank_Customer_Churn_Dataset mlp IsolationForest
# [2026-03-19 15:32:30] Classification metrics can't handle a mix of binary and continuous targets
# [2026-03-19 15:32:30] RUN 4/180 (2.2%) Bank_Customer_Churn_Dataset mlp IQR
# [2026-03-19 15:32:34] EXPERIMENT FAILED Bank_Customer_Churn_Dataset mlp IQR
# [2026-03-19 15:32:34] Classification metrics can't handle a mix of binary and continuous targets
# [2026-03-19 15:32:34] RUN 5/180 (2.8%) Bank_Customer_Churn_Dataset xgboost None
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [15:32:36] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 15:32:36] Bank_Customer_Churn_Dataset xgboost None run=0 score=0.84200 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [15:32:38] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 15:32:38] Bank_Customer_Churn_Dataset xgboost None run=1 score=0.83650 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [15:32:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 15:32:40] Bank_Customer_Churn_Dataset xgboost None run=2 score=0.82750 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [15:32:42] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 15:32:42] Bank_Customer_Churn_Dataset xgboost None run=3 score=0.83100 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [15:32:44] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 15:32:45] Bank_Customer_Churn_Dataset xgboost None run=4 score=0.77350 removed=0 (0.000)
# [2026-03-19 15:32:45] RESULT Bank_Customer_Churn_Dataset xgboost None mean=0.82210 std=0.02479 removed=0.0 (0.000)
# [2026-03-19 15:32:45] RUN 6/180 (3.3%) Bank_Customer_Churn_Dataset xgboost ZScore
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 878
#     874     log_text("Experiment finished")
#     876 if __name__=="__main__":
# --> 878     main()
#
# Cell In[5], line 828, in main()
#     820 try:
#     822     log_text(
#     823     f"RUN {counter}/{total} "
#     824     f"({progress:.1f}%) "
#     825     f"{label}"
#     826     )
# --> 828     res = run_experiment(
#     829
#     830         dataset,
#     831         model,
#     832         outlier
#     833     )
#     835     log_text(
#     836
#     837     f"RESULT {label} "
#    (...)    845     f"({res['removed_pct']:.3f})"
#     846     )
#     848     log_summary(
#     849
#     850         dataset,
#    (...)    853         res
#     854     )
#
# Cell In[5], line 614, in run_experiment(dataset, model, outlier)
#     610 for i in range(RUNS):
#     612     seed=42+i
# --> 614     result=single_run(
#     615
#     616         dataset,
#     617
#     618         model,
#     619
#     620         outlier,
#     621
#     622         seed
#     623     )
#     625     scores.append(result["score"])
#     627     removed.append(result["removed"])
#
# Cell In[5], line 492, in single_run(dataset, model, outlier, seed)
#     488         X_train[col] = le.fit_transform(X_train[col].astype(str))
#     490         X_test[col] = X_test[col].astype(str)
# --> 492         X_test[col] = X_test[col].map(
#     493
#     494             lambda x:
#     495             le.transform([x])[0]
#     496             if x in le.classes_
#     497             else 0
#     498         )
#     500 # PREPROCESS
#     501 X_train,means,stds = preprocess_train(X_train)
#
# File ~/code/tabular-nns/env/lib/python3.12/site-packages/pandas/core/series.py:4719, in Series.map(self, arg, na_action)
#    4639 def map(
#    4640     self,
#    4641     arg: Callable | Mapping | Series,
#    4642     na_action: Literal["ignore"] | None = None,
#    4643 ) -> Series:
#    4644     """
#    4645     Map values of Series according to an input mapping or function.
#    4646
#    (...)   4717     dtype: object
#    4718     """
# -> 4719     new_values = self._map_values(arg, na_action=na_action)
#    4720     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4721         self, method="map"
#    4722     )
#
# File ~/code/tabular-nns/env/lib/python3.12/site-packages/pandas/core/base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/code/tabular-nns/env/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[5], line 495, in single_run.<locals>.<lambda>(x)
#     488         X_train[col] = le.fit_transform(X_train[col].astype(str))
#     490         X_test[col] = X_test[col].astype(str)
#     492         X_test[col] = X_test[col].map(
#     493
#     494             lambda x:
# --> 495             le.transform([x])[0]
#     496             if x in le.classes_
#     497             else 0
#     498         )
#     500 # PREPROCESS
#     501 X_train,means,stds = preprocess_train(X_train)
#
# File ~/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:114, in LabelEncoder.transform(self, y)
#     111     self.classes_, y = _unique(y, return_inverse=True)
#     112     return y
# --> 114 def transform(self, y):
#     115     """Transform labels to normalized encoding.
#     116
#     117     Parameters
#    (...)    125         Labels as normalized encodings.
#     126     """
#     127     check_is_fitted(self)
#
# KeyboardInterrupt:

# %%
res = run_experiment(
    dataset="electricity",
    model="xgboost",
    outlier=None
)

print("\nRESULT:")
print("Mean:", res["mean"])
print("Std:", res["std"])
print("All runs:", res["all"])
# Out:
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:51] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# RESULT:
# Mean: 0.7837360697340836
# Std: 0.0
# All runs: [0.7837360697340836, 0.7837360697340836, 0.7837360697340836, 0.7837360697340836, 0.7837360697340836]

# %%
run_experiment("cmc","mlp",None)
# Out:
# {'mean': np.float64(0.5850847457627119),
#  'std': np.float64(0.007906375450637698),
#  'min': np.float64(0.576271186440678),
#  'max': np.float64(0.5966101694915255),
#  'removed_mean': np.float64(0.0),
#  'time_mean': np.float64(0.26859517097473146),
#  'all': [0.576271186440678,
#   0.5864406779661017,
#   0.5966101694915255,
#   0.5898305084745763,
#   0.576271186440678]}

# %%
run_experiment("eucalyptus","xgboost",None)
run_experiment("eucalyptus","xgboost","ZScore")
# Out:
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:26] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:27] eucalyptus xgboost None run=0 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:27] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:29] eucalyptus xgboost None run=1 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:29] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:30] eucalyptus xgboost None run=2 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:30] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:31] eucalyptus xgboost None run=3 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:32] eucalyptus xgboost None run=4 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:32] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:33] eucalyptus xgboost ZScore run=0 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:33] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:33] eucalyptus xgboost ZScore run=1 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:33] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:34] eucalyptus xgboost ZScore run=2 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:34] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:35] eucalyptus xgboost ZScore run=3 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:35] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:36] eucalyptus xgboost ZScore run=4 score=0.24324 removed=0 (0.000)
# {'mean': np.float64(0.24324324324324326),
#  'std': np.float64(0.0),
#  'min': np.float64(0.24324324324324326),
#  'max': np.float64(0.24324324324324326),
#  'train_size': 470,
#  'removed_mean': np.float64(0.0),
#  'removed_pct': np.float64(0.0),
#  'time_mean': np.float64(0.6785444736480712),
#  'all': [0.24324324324324326,
#   0.24324324324324326,
#   0.24324324324324326,
#   0.24324324324324326,
#   0.24324324324324326]}
