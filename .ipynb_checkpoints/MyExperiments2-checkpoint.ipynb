# %%
#!/usr/bin/env python3

import os
import json
import time
import numpy as np
import pandas as pd

from pathlib import Path

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, mean_squared_error

from sklearn.ensemble import IsolationForest
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

from sklearn.svm import OneClassSVM

from sklearn.linear_model import LogisticRegression, LinearRegression

from sklearn.neural_network import MLPClassifier, MLPRegressor

from xgboost import XGBClassifier, XGBRegressor


########################################
# CONFIG
########################################

DATA_PATH="data"

DATASETS=[
"Bank_Customer_Churn_Dataset",
"cmc",
"connect-4",
"credit-g",
"electricity",
"elevators",
"eucalyptus",
"eye_movements",
"house_16H",
"kc1",
"phoneme",
"pol",
"socmob",
"splice",
"vehicle"
]

MODELS=[
    "mlp",
    "xgboost",
    "randomforest"
]

OUTLIERS=[
    None,
    "ZScore",
    "IsolationForest",
    "IQR"
]

RUNS=5


########################################
# LOGGING UTILITIES
########################################

def log_text(message):

    timestamp=time.strftime("%Y-%m-%d %H:%M:%S")

    line=f"[{timestamp}] {message}"

    print(line)

    with open("results/experiment_log.txt","a") as f:

        f.write(line+"\n")


def experiment_done(dataset,model,outlier):

    path="results/summary.csv"

    if not os.path.exists(path):

        return False

    df=pd.read_csv(path)

    return ((df.dataset==dataset)&
            (df.model==model)&
            (df.outlier.astype(str)==str(outlier))).any()


########################################
# DATA LOADING
########################################

def load_json(path):

    return json.loads(Path(path).read_text())


def load_dataset(dataset):

    base=Path(DATA_PATH)/dataset

    def load_block(name):

        return {

            x:np.load(
                base/f"{name}_{x}.npy",
                allow_pickle=True
            )

            for x in ["train","val","test"]
        }

    N=load_block("N") if (base/"N_train.npy").exists() else None

    C=load_block("C") if (base/"C_train.npy").exists() else None

    y=load_block("y")

    info=load_json(base/"info.json")

    return N,C,y,info


########################################
# PREPROCESSING
########################################

def preprocess_train(X):

    X=pd.DataFrame(X)

    numeric_cols=X.select_dtypes(include=[np.number]).columns

    means={}
    stds={}

    for col in numeric_cols:

        mean=X[col].mean()

        X[col]=X[col].fillna(mean)

        std=X[col].std()

        if std==0:

            std=1

        X[col]=(X[col]-mean)/std

        means[col]=mean
        stds[col]=std

    X = X.fillna(0).infer_objects(copy=False)

    return X.values,means,stds


def preprocess_test(X,means,stds):

    X=pd.DataFrame(X)

    for col in means:

        if col in X:

            X[col]=X[col].fillna(means[col])

            X[col]=(X[col]-means[col])/stds[col]

    X = X.fillna(0).infer_objects(copy=False)

    return X.values


########################################
# OUTLIERS
########################################

def detect_outliers(X,method,seed):

    # ensure numeric numpy array
    X = np.asarray(X)

    # convert possible object dtype safely
    if X.dtype == object:

        X = pd.DataFrame(X).apply(
            pd.to_numeric,
            errors="coerce"
        ).values

    # replace NaN produced by coercion
    X = np.nan_to_num(X)

    # ensure stable numeric type
    X = X.astype(np.float64)

    CONTAMINATION = 0.05

    if method is None:

        return np.ones(len(X),dtype=bool)

    if method=="ZScore":

        mean = X.mean(0)

        std = X.std(0)

        std[std == 0] = 1

        z = np.abs((X-mean)/std)

        return (z < 3).all(1)

    if method=="IQR":

        Q1 = np.percentile(X,25,axis=0)

        Q3 = np.percentile(X,75,axis=0)

        IQR = Q3-Q1

        lower = Q1-1.5*IQR

        upper = Q3+1.5*IQR

        return ((X>=lower)&
                (X<=upper)).all(1)

    if method=="IsolationForest":

        clf = IsolationForest(

            n_estimators=200,

            contamination=CONTAMINATION,

            random_state=seed
        )

        return clf.fit_predict(X)==1

    if method=="OneClassSVM":

        clf = OneClassSVM(

            nu=CONTAMINATION,

            kernel="rbf",

            gamma="scale"
        )

        return clf.fit_predict(X)==1

    raise ValueError("Unknown method")


########################################
# MODELS
########################################

def make_model(name,task,seed):

    name=name.lower()

    if name=="mlp":

        if task=="classification":

            return MLPClassifier(

                hidden_layer_sizes=(100,),

                max_iter=500,

                random_state=seed,

                shuffle=True
            )

        return MLPRegressor(

            hidden_layer_sizes=(100,),

            max_iter=500,

            random_state=seed
        )

    if name=="xgboost":

        if task=="classification":

            return XGBClassifier(

                use_label_encoder=False,

                eval_metric="logloss",

                random_state=seed
            )

        return XGBRegressor(random_state=seed)

    if name=="randomforest":

        if task=="classification":

            return RandomForestClassifier(

                n_estimators=100,

                random_state=seed
            )

        return RandomForestRegressor(

            n_estimators=100,

            random_state=seed
        )

    if name=="linear":

        if task=="classification":

            return LogisticRegression(max_iter=1000)

        return LinearRegression()

    raise ValueError("Unknown model")


########################################
# SINGLE RUN
########################################

def single_run(dataset,model,outlier,seed):

    np.random.seed(seed)

    N,C,y,info=load_dataset(dataset)

    # Ensure N only contains numeric data
    
    if N is not None:
    
        N_df = pd.DataFrame(N["train"])
    
        numeric_cols = N_df.select_dtypes(include=[np.number]).columns
    
        if len(numeric_cols) != N_df.shape[1]:
    
            # split numeric and categorical automatically
            numeric_data = N_df[numeric_cols].values
    
            categorical_data = N_df.drop(columns=numeric_cols).values
    
            N["train"] = numeric_data
    
            if C is None:
    
                C = {}
    
                C["train"] = categorical_data
    
                C["test"] = pd.DataFrame(N["test"]).drop(columns=numeric_cols).values
    
            else:
    
                C["train"] = np.hstack([C["train"],categorical_data])

    y_train=y["train"].ravel()

    y_test=y["test"].ravel()

    perm=np.random.permutation(len(y_train))

    y_train=y_train[perm]

    N["train"]=N["train"][perm]

    if C is not None:

        C["train"]=C["train"][perm]

    if N is not None:

        before=len(N["train"])
    
    else:
    
        before=len(C["train"])

    mask=detect_outliers(

        N["train"],

        outlier,

        seed
    )

    N["train"]=N["train"][mask]

    y_train=y_train[mask]

    if C is not None:

        C["train"]=C["train"][mask]

    after=len(N["train"])

    removed=before-after

    if C is not None:

        X_train=np.hstack([

            N["train"],

            C["train"]

        ])

        X_test=np.hstack([

            N["test"],

            C["test"]

        ])

    else:

        X_train=N["train"]

        X_test=N["test"]

    # convert to DataFrame for safe handling
    X_train = pd.DataFrame(X_train)
    X_test = pd.DataFrame(X_test)
    
    # encode categorical columns
    for col in X_train.columns:
    
        if X_train[col].dtype == object:
    
            le = LabelEncoder()
    
            X_train[col] = le.fit_transform(X_train[col].astype(str))
    
            X_test[col] = X_test[col].astype(str)
    
            # handle unseen values safely
            X_test[col] = X_test[col].map(
                lambda x: le.transform([x])[0] if x in le.classes_ else 0
            )
    
    # now preprocess numeric scaling
    X_train,means,stds = preprocess_train(X_train)
    
    X_test = preprocess_test(
        X_test,
        means,
        stds
    )

    perm=np.random.permutation(len(X_train))

    X_train=X_train[perm]

    y_train=y_train[perm]

    task=info["task_type"]

    if task!="regression":

        task="classification"

    if task=="classification":

        le=LabelEncoder()

        y_train=le.fit_transform(y_train)

        y_test=le.transform(y_test)

    model=make_model(

        model,

        task,

        seed
    )

    start=time.time()

    model.fit(X_train,y_train)

    train_time=time.time()-start

    score=evaluate(

        model,

        X_test,

        y_test,

        task
    )

    return {

        "score":score,

        "train_before":before,

        "train_after":after,

        "removed":removed,

        "removed_pct":removed/before if before>0 else 0,

        "time":train_time
    }


########################################
# EVALUATION
########################################

def evaluate(model,X,y,task):

    pred=model.predict(X)

    if task=="classification":

        return accuracy_score(y,pred)

    return mean_squared_error(y,pred)


########################################
# EXPERIMENT LOOP
########################################

def run_experiment(dataset,model,outlier):

    scores=[]

    removed=[]

    removed_pct=[]

    times=[]

    train_sizes=[]

    for i in range(RUNS):

        seed=42+i

        result=single_run(

            dataset,

            model,

            outlier,

            seed
        )

        scores.append(result["score"])

        removed.append(result["removed"])

        removed_pct.append(result["removed_pct"])

        times.append(result["time"])

        train_sizes.append(result["train_before"])

        log_text(

        f"{dataset} {model} {outlier} "

        f"run={i} "

        f"score={result['score']:.5f} "

        f"removed={result['removed']} "

        f"({result['removed_pct']:.3f})"
        )

    scores=np.array(scores)

    return {

        "mean":scores.mean(),

        "std":scores.std(),

        "min":scores.min(),

        "max":scores.max(),

        "train_size":int(np.mean(train_sizes)),

        "removed_mean":np.mean(removed),

        "removed_pct":np.mean(removed_pct),

        "time_mean":np.mean(times),

        "all":scores.tolist()
    }


########################################
# LOGGING
########################################

def init_logs():

    os.makedirs("results",exist_ok=True)

    if not os.path.exists("results/summary.csv"):

        with open("results/summary.csv","w") as f:

            f.write(

            "dataset,model,outlier,mean,std,min,max,train_size,removed,removed_pct,time\n"

            )

    if not os.path.exists("results/runs.csv"):

        with open("results/runs.csv","w") as f:

            f.write(

            "dataset,model,outlier,run,seed,score\n"

            )

    with open("results/experiment_log.txt","a") as f:

        f.write("\n====================\n")

        f.write(

        "START "+time.strftime("%Y-%m-%d %H:%M:%S")+"\n"
        )


def log_summary(dataset,model,outlier,res):

    with open("results/summary.csv","a") as f:

        f.write(

        f"{dataset},{model},{outlier},"

        f"{res['mean']:.5f},"

        f"{res['std']:.5f},"

        f"{res['min']:.5f},"

        f"{res['max']:.5f},"

        f"{res['train_size']},"

        f"{res['removed_mean']:.2f},"

        f"{res['removed_pct']:.4f},"

        f"{res['time_mean']:.3f}\n"
        )


def log_runs(dataset,model,outlier,res):

    with open("results/runs.csv","a") as f:

        for i,score in enumerate(res["all"]):

            seed=42+i

            f.write(

            f"{dataset},{model},{outlier},{i},{seed},{score:.5f}\n"

            )


########################################
# MAIN
########################################

def main():

    init_logs()

    log_text("Experiment started")

    total = len(DATASETS)*len(MODELS)*len(OUTLIERS)

    total_runs = total * RUNS

    log_text("===== EXPERIMENT SETUP =====")

    log_text(f"Datasets: {DATASETS}")

    log_text(f"Models: {MODELS}")

    log_text(f"Outliers: {OUTLIERS}")

    log_text(f"Runs per experiment: {RUNS}")

    log_text(f"Total experiments: {total}")

    log_text(f"Total model trainings: {total_runs}")

    log_text("============================")

    counter = 0

    for dataset in DATASETS:

        log_text(f"==== DATASET {dataset} ====")

        try:

            # quick dataset test
            load_dataset(dataset)

        except Exception as e:

            log_text(f"DATASET FAILED {dataset}")

            log_text(str(e))

            continue

        for model in MODELS:

            for outlier in OUTLIERS:

                counter += 1

                progress = 100*counter/total

                label = f"{dataset} {model} {outlier}"

                if experiment_done(dataset,model,outlier):

                    log_text(
                    f"SKIP {counter}/{total} "
                    f"({progress:.1f}%) "
                    f"{label}"
                    )

                    continue

                try:

                    log_text(
                    f"RUN {counter}/{total} "
                    f"({progress:.1f}%) "
                    f"{label}"
                    )

                    res = run_experiment(

                        dataset,
                        model,
                        outlier
                    )

                    log_text(

                    f"RESULT {label} "

                    f"mean={res['mean']:.5f} "

                    f"std={res['std']:.5f} "

                    f"removed={res['removed_mean']:.1f} "

                    f"({res['removed_pct']:.3f})"
                    )

                    log_summary(

                        dataset,
                        model,
                        outlier,
                        res
                    )

                    log_runs(

                        dataset,
                        model,
                        outlier,
                        res
                    )

                except Exception as e:

                    log_text(f"EXPERIMENT FAILED {label}")

                    log_text(str(e))

                    continue

        log_text(f"==== DATASET {dataset} DONE ====")

    log_text("Experiment finished")

if __name__=="__main__":

    main()
# Out:
# [2026-03-19 11:44:51] Experiment started
# [2026-03-19 11:44:51] ===== EXPERIMENT SETUP =====
# [2026-03-19 11:44:51] Datasets: ['Bank_Customer_Churn_Dataset', 'cmc', 'connect-4', 'credit-g', 'electricity', 'elevators', 'eucalyptus', 'eye_movements', 'house_16H', 'kc1', 'phoneme', 'pol', 'socmob', 'splice', 'vehicle']
# [2026-03-19 11:44:51] Models: ['mlp', 'xgboost', 'randomforest']
# [2026-03-19 11:44:51] Outliers: [None, 'ZScore', 'IsolationForest', 'IQR']
# [2026-03-19 11:44:51] Runs per experiment: 5
# [2026-03-19 11:44:51] Total experiments: 180
# [2026-03-19 11:44:51] Total model trainings: 900
# [2026-03-19 11:44:51] ============================
# [2026-03-19 11:44:51] ==== DATASET Bank_Customer_Churn_Dataset ====
# [2026-03-19 11:44:51] RUN 1/180 (0.6%) Bank_Customer_Churn_Dataset mlp None
# [2026-03-19 11:44:51] EXPERIMENT FAILED Bank_Customer_Churn_Dataset mlp None
# [2026-03-19 11:44:51] could not convert string to float: 'France'
# [2026-03-19 11:44:51] RUN 2/180 (1.1%) Bank_Customer_Churn_Dataset mlp ZScore
# [2026-03-19 11:44:51] EXPERIMENT FAILED Bank_Customer_Churn_Dataset mlp ZScore
# [2026-03-19 11:44:51] could not convert string to float: 'France'
# [2026-03-19 11:44:51] RUN 3/180 (1.7%) Bank_Customer_Churn_Dataset mlp IsolationForest
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:51] EXPERIMENT FAILED Bank_Customer_Churn_Dataset mlp IsolationForest
# [2026-03-19 11:44:51] could not convert string to float: 'France'
# [2026-03-19 11:44:51] RUN 4/180 (2.2%) Bank_Customer_Churn_Dataset mlp IQR
# [2026-03-19 11:44:52] EXPERIMENT FAILED Bank_Customer_Churn_Dataset mlp IQR
# [2026-03-19 11:44:52] could not convert string to float: 'Germany'
# [2026-03-19 11:44:52] RUN 5/180 (2.8%) Bank_Customer_Churn_Dataset xgboost None
# [2026-03-19 11:44:53] EXPERIMENT FAILED Bank_Customer_Churn_Dataset xgboost None
# [2026-03-19 11:44:53] could not convert string to float: 'France'
# [2026-03-19 11:44:53] RUN 6/180 (3.3%) Bank_Customer_Churn_Dataset xgboost ZScore
# [2026-03-19 11:44:53] EXPERIMENT FAILED Bank_Customer_Churn_Dataset xgboost ZScore
# [2026-03-19 11:44:53] could not convert string to float: 'France'
# [2026-03-19 11:44:53] RUN 7/180 (3.9%) Bank_Customer_Churn_Dataset xgboost IsolationForest
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:54] EXPERIMENT FAILED Bank_Customer_Churn_Dataset xgboost IsolationForest
# [2026-03-19 11:44:54] could not convert string to float: 'France'
# [2026-03-19 11:44:54] RUN 8/180 (4.4%) Bank_Customer_Churn_Dataset xgboost IQR
# [2026-03-19 11:44:54] EXPERIMENT FAILED Bank_Customer_Churn_Dataset xgboost IQR
# [2026-03-19 11:44:54] could not convert string to float: 'Germany'
# [2026-03-19 11:44:54] RUN 9/180 (5.0%) Bank_Customer_Churn_Dataset randomforest None
# [2026-03-19 11:44:54] EXPERIMENT FAILED Bank_Customer_Churn_Dataset randomforest None
# [2026-03-19 11:44:54] could not convert string to float: 'France'
# [2026-03-19 11:44:54] RUN 10/180 (5.6%) Bank_Customer_Churn_Dataset randomforest ZScore
# [2026-03-19 11:44:54] EXPERIMENT FAILED Bank_Customer_Churn_Dataset randomforest ZScore
# [2026-03-19 11:44:54] could not convert string to float: 'France'
# [2026-03-19 11:44:54] RUN 11/180 (6.1%) Bank_Customer_Churn_Dataset randomforest IsolationForest
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:54] EXPERIMENT FAILED Bank_Customer_Churn_Dataset randomforest IsolationForest
# [2026-03-19 11:44:54] could not convert string to float: 'France'
# [2026-03-19 11:44:54] RUN 12/180 (6.7%) Bank_Customer_Churn_Dataset randomforest IQR
# [2026-03-19 11:44:54] EXPERIMENT FAILED Bank_Customer_Churn_Dataset randomforest IQR
# [2026-03-19 11:44:54] could not convert string to float: 'Germany'
# [2026-03-19 11:44:54] ==== DATASET Bank_Customer_Churn_Dataset DONE ====
# [2026-03-19 11:44:54] ==== DATASET cmc ====
# [2026-03-19 11:44:54] RUN 13/180 (7.2%) cmc mlp None
# [2026-03-19 11:44:54] cmc mlp None run=0 score=0.57627 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:54] cmc mlp None run=1 score=0.58644 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:55] cmc mlp None run=2 score=0.59661 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:55] cmc mlp None run=3 score=0.58983 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:55] cmc mlp None run=4 score=0.57627 removed=0 (0.000)
# [2026-03-19 11:44:55] RESULT cmc mlp None mean=0.58508 std=0.00791 removed=0.0 (0.000)
# [2026-03-19 11:44:55] SKIP 14/180 (7.8%) cmc mlp ZScore
# [2026-03-19 11:44:55] SKIP 15/180 (8.3%) cmc mlp IsolationForest
# [2026-03-19 11:44:55] SKIP 16/180 (8.9%) cmc mlp IQR
# [2026-03-19 11:44:55] RUN 17/180 (9.4%) cmc xgboost None
# [2026-03-19 11:44:55] cmc xgboost None run=0 score=0.51186 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:55] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:55] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 11:44:55] cmc xgboost None run=1 score=0.51186 removed=0 (0.000)
# [2026-03-19 11:44:56] cmc xgboost None run=2 score=0.51186 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:55] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:56] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 11:44:56] cmc xgboost None run=3 score=0.51186 removed=0 (0.000)
# [2026-03-19 11:44:56] cmc xgboost None run=4 score=0.51186 removed=0 (0.000)
# [2026-03-19 11:44:56] RESULT cmc xgboost None mean=0.51186 std=0.00000 removed=0.0 (0.000)
# [2026-03-19 11:44:56] SKIP 18/180 (10.0%) cmc xgboost ZScore
# [2026-03-19 11:44:56] SKIP 19/180 (10.6%) cmc xgboost IsolationForest
# [2026-03-19 11:44:56] SKIP 20/180 (11.1%) cmc xgboost IQR
# [2026-03-19 11:44:56] RUN 21/180 (11.7%) cmc randomforest None
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:56] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:56] cmc randomforest None run=0 score=0.52203 removed=0 (0.000)
# [2026-03-19 11:44:56] cmc randomforest None run=1 score=0.52881 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:56] cmc randomforest None run=2 score=0.50847 removed=0 (0.000)
# [2026-03-19 11:44:56] cmc randomforest None run=3 score=0.51525 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:56] cmc randomforest None run=4 score=0.52881 removed=0 (0.000)
# [2026-03-19 11:44:56] RESULT cmc randomforest None mean=0.52068 std=0.00791 removed=0.0 (0.000)
# [2026-03-19 11:44:56] SKIP 22/180 (12.2%) cmc randomforest ZScore
# [2026-03-19 11:44:56] SKIP 23/180 (12.8%) cmc randomforest IsolationForest
# [2026-03-19 11:44:56] SKIP 24/180 (13.3%) cmc randomforest IQR
# [2026-03-19 11:44:56] ==== DATASET cmc DONE ====
# [2026-03-19 11:44:56] ==== DATASET connect-4 ====
# [2026-03-19 11:44:56] RUN 25/180 (13.9%) connect-4 mlp None
# [2026-03-19 11:44:56] EXPERIMENT FAILED connect-4 mlp None
# [2026-03-19 11:44:56] 'NoneType' object is not subscriptable
# [2026-03-19 11:44:56] RUN 26/180 (14.4%) connect-4 mlp ZScore
# [2026-03-19 11:44:57] EXPERIMENT FAILED connect-4 mlp ZScore
# [2026-03-19 11:44:57] 'NoneType' object is not subscriptable
# [2026-03-19 11:44:57] RUN 27/180 (15.0%) connect-4 mlp IsolationForest
# [2026-03-19 11:44:57] EXPERIMENT FAILED connect-4 mlp IsolationForest
# [2026-03-19 11:44:57] 'NoneType' object is not subscriptable
# [2026-03-19 11:44:57] RUN 28/180 (15.6%) connect-4 mlp IQR
# [2026-03-19 11:44:57] EXPERIMENT FAILED connect-4 mlp IQR
# [2026-03-19 11:44:57] 'NoneType' object is not subscriptable
# [2026-03-19 11:44:57] RUN 29/180 (16.1%) connect-4 xgboost None
# [2026-03-19 11:44:57] EXPERIMENT FAILED connect-4 xgboost None
# [2026-03-19 11:44:57] 'NoneType' object is not subscriptable
# [2026-03-19 11:44:57] RUN 30/180 (16.7%) connect-4 xgboost ZScore
# [2026-03-19 11:44:57] EXPERIMENT FAILED connect-4 xgboost ZScore
# [2026-03-19 11:44:57] 'NoneType' object is not subscriptable
# [2026-03-19 11:44:57] RUN 31/180 (17.2%) connect-4 xgboost IsolationForest
# [2026-03-19 11:44:57] EXPERIMENT FAILED connect-4 xgboost IsolationForest
# [2026-03-19 11:44:57] 'NoneType' object is not subscriptable
# [2026-03-19 11:44:57] RUN 32/180 (17.8%) connect-4 xgboost IQR
# [2026-03-19 11:44:57] EXPERIMENT FAILED connect-4 xgboost IQR
# [2026-03-19 11:44:57] 'NoneType' object is not subscriptable
# [2026-03-19 11:44:57] RUN 33/180 (18.3%) connect-4 randomforest None
# [2026-03-19 11:44:57] EXPERIMENT FAILED connect-4 randomforest None
# [2026-03-19 11:44:57] 'NoneType' object is not subscriptable
# [2026-03-19 11:44:57] RUN 34/180 (18.9%) connect-4 randomforest ZScore
# [2026-03-19 11:44:57] EXPERIMENT FAILED connect-4 randomforest ZScore
# [2026-03-19 11:44:57] 'NoneType' object is not subscriptable
# [2026-03-19 11:44:57] RUN 35/180 (19.4%) connect-4 randomforest IsolationForest
# [2026-03-19 11:44:57] EXPERIMENT FAILED connect-4 randomforest IsolationForest
# [2026-03-19 11:44:57] 'NoneType' object is not subscriptable
# [2026-03-19 11:44:57] RUN 36/180 (20.0%) connect-4 randomforest IQR
# [2026-03-19 11:44:57] EXPERIMENT FAILED connect-4 randomforest IQR
# [2026-03-19 11:44:57] 'NoneType' object is not subscriptable
# [2026-03-19 11:44:57] ==== DATASET connect-4 DONE ====
# [2026-03-19 11:44:57] ==== DATASET credit-g ====
# [2026-03-19 11:44:57] RUN 37/180 (20.6%) credit-g mlp None
# [2026-03-19 11:44:57] credit-g mlp None run=0 score=0.30000 removed=0 (0.000)
# [2026-03-19 11:44:57] credit-g mlp None run=1 score=0.70000 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:57] credit-g mlp None run=2 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:57] credit-g mlp None run=3 score=0.30000 removed=0 (0.000)
# [2026-03-19 11:44:57] credit-g mlp None run=4 score=0.30000 removed=0 (0.000)
# [2026-03-19 11:44:57] RESULT credit-g mlp None mean=0.46000 std=0.19596 removed=0.0 (0.000)
# [2026-03-19 11:44:57] RUN 38/180 (21.1%) credit-g mlp ZScore
# [2026-03-19 11:44:57] credit-g mlp ZScore run=0 score=0.30000 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:57] credit-g mlp ZScore run=1 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:57] credit-g mlp ZScore run=2 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:58] credit-g mlp ZScore run=3 score=0.30000 removed=0 (0.000)
# [2026-03-19 11:44:58] credit-g mlp ZScore run=4 score=0.30000 removed=0 (0.000)
# [2026-03-19 11:44:58] RESULT credit-g mlp ZScore mean=0.46000 std=0.19596 removed=0.0 (0.000)
# [2026-03-19 11:44:58] SKIP 39/180 (21.7%) credit-g mlp IsolationForest
# [2026-03-19 11:44:58] SKIP 40/180 (22.2%) credit-g mlp IQR
# [2026-03-19 11:44:58] RUN 41/180 (22.8%) credit-g xgboost None
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 11:44:58] credit-g xgboost None run=0 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:58] credit-g xgboost None run=1 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:58] credit-g xgboost None run=2 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:58] credit-g xgboost None run=3 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:58] credit-g xgboost None run=4 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:58] RESULT credit-g xgboost None mean=0.70000 std=0.00000 removed=0.0 (0.000)
# [2026-03-19 11:44:58] RUN 42/180 (23.3%) credit-g xgboost ZScore
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 11:44:58] credit-g xgboost ZScore run=0 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:58] credit-g xgboost ZScore run=1 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:58] credit-g xgboost ZScore run=2 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:58] credit-g xgboost ZScore run=3 score=0.70000 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:44:58] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:58] credit-g xgboost ZScore run=4 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:58] RESULT credit-g xgboost ZScore mean=0.70000 std=0.00000 removed=0.0 (0.000)
# [2026-03-19 11:44:58] SKIP 43/180 (23.9%) credit-g xgboost IsolationForest
# [2026-03-19 11:44:58] SKIP 44/180 (24.4%) credit-g xgboost IQR
# [2026-03-19 11:44:58] RUN 45/180 (25.0%) credit-g randomforest None
# [2026-03-19 11:44:58] credit-g randomforest None run=0 score=0.71500 removed=0 (0.000)
# [2026-03-19 11:44:58] credit-g randomforest None run=1 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:58] credit-g randomforest None run=2 score=0.70000 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:44:59] credit-g randomforest None run=3 score=0.70000 removed=0 (0.000)
# [2026-03-19 11:44:59] credit-g randomforest None run=4 score=0.72000 removed=0 (0.000)
# [2026-03-19 11:44:59] RESULT credit-g randomforest None mean=0.70700 std=0.00872 removed=0.0 (0.000)
# [2026-03-19 11:44:59] RUN 46/180 (25.6%) credit-g randomforest ZScore
# ...
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:46:22] eucalyptus randomforest IQR run=3 score=0.25000 removed=0 (0.000)
# [2026-03-19 11:46:22] eucalyptus randomforest IQR run=4 score=0.20270 removed=0 (0.000)
# [2026-03-19 11:46:22] RESULT eucalyptus randomforest IQR mean=0.23514 std=0.05275 removed=0.0 (0.000)
# [2026-03-19 11:46:22] ==== DATASET eucalyptus DONE ====
# [2026-03-19 11:46:22] ==== DATASET eye_movements ====
# [2026-03-19 11:46:22] RUN 85/180 (47.2%) eye_movements mlp None
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:46:23] eye_movements mlp None run=0 score=0.37843 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:46:23] eye_movements mlp None run=1 score=0.42322 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:46:24] eye_movements mlp None run=2 score=0.39442 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:46:24] eye_movements mlp None run=3 score=0.38803 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:46:25] eye_movements mlp None run=4 score=0.40037 removed=0 (0.000)
# [2026-03-19 11:46:25] RESULT eye_movements mlp None mean=0.39689 std=0.01504 removed=0.0 (0.000)
# [2026-03-19 11:46:25] SKIP 86/180 (47.8%) eye_movements mlp ZScore
# [2026-03-19 11:46:25] SKIP 87/180 (48.3%) eye_movements mlp IsolationForest
# [2026-03-19 11:46:25] SKIP 88/180 (48.9%) eye_movements mlp IQR
# [2026-03-19 11:46:25] RUN 89/180 (49.4%) eye_movements xgboost None
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:46:25] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 11:46:25] eye_movements xgboost None run=0 score=0.68967 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:46:25] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 11:46:26] eye_movements xgboost None run=1 score=0.68967 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:46:26] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 11:46:26] eye_movements xgboost None run=2 score=0.68967 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:46:26] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 11:46:26] eye_movements xgboost None run=3 score=0.68967 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [11:46:26] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 11:46:27] eye_movements xgboost None run=4 score=0.68967 removed=0 (0.000)
# [2026-03-19 11:46:27] RESULT eye_movements xgboost None mean=0.68967 std=0.00000 removed=0.0 (0.000)
# [2026-03-19 11:46:27] SKIP 90/180 (50.0%) eye_movements xgboost ZScore
# [2026-03-19 11:46:27] SKIP 91/180 (50.6%) eye_movements xgboost IsolationForest
# [2026-03-19 11:46:27] SKIP 92/180 (51.1%) eye_movements xgboost IQR
# [2026-03-19 11:46:27] RUN 93/180 (51.7%) eye_movements randomforest None
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:46:28] eye_movements randomforest None run=0 score=0.65951 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:46:30] eye_movements randomforest None run=1 score=0.66408 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:46:31] eye_movements randomforest None run=2 score=0.65676 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:46:34] eye_movements randomforest None run=3 score=0.66179 removed=0 (0.000)
# /tmp/ipykernel_4884/3019507383.py:164: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# /tmp/ipykernel_4884/3019507383.py:181: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X = X.fillna(0)
# [2026-03-19 11:46:36] eye_movements randomforest None run=4 score=0.66545 removed=0 (0.000)
# [2026-03-19 11:46:36] RESULT eye_movements randomforest None mean=0.66152 std=0.00312 removed=0.0 (0.000)
# [2026-03-19 11:46:36] SKIP 94/180 (52.2%) eye_movements randomforest ZScore
# [2026-03-19 11:46:36] SKIP 95/180 (52.8%) eye_movements randomforest IsolationForest
# [2026-03-19 11:46:36] SKIP 96/180 (53.3%) eye_movements randomforest IQR
# [2026-03-19 11:46:36] ==== DATASET eye_movements DONE ====
# [2026-03-19 11:46:36] ==== DATASET house_16H ====
# [2026-03-19 11:46:36] RUN 97/180 (53.9%) house_16H mlp None
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:788: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [2026-03-19 11:46:37] house_16H mlp None run=0 score=0.87064 removed=0 (0.000)
# [2026-03-19 11:46:41] house_16H mlp None run=1 score=0.86694 removed=0 (0.000)

# %%
res = run_experiment(
    dataset="electricity",
    model="xgboost",
    outlier=None
)

print("\nRESULT:")
print("Mean:", res["mean"])
print("Std:", res["std"])
print("All runs:", res["all"])
# Out:
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:51] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# RESULT:
# Mean: 0.7837360697340836
# Std: 0.0
# All runs: [0.7837360697340836, 0.7837360697340836, 0.7837360697340836, 0.7837360697340836, 0.7837360697340836]

# %%
run_experiment("cmc","mlp",None)
# Out:
# {'mean': np.float64(0.5850847457627119),
#  'std': np.float64(0.007906375450637698),
#  'min': np.float64(0.576271186440678),
#  'max': np.float64(0.5966101694915255),
#  'removed_mean': np.float64(0.0),
#  'time_mean': np.float64(0.26859517097473146),
#  'all': [0.576271186440678,
#   0.5864406779661017,
#   0.5966101694915255,
#   0.5898305084745763,
#   0.576271186440678]}
