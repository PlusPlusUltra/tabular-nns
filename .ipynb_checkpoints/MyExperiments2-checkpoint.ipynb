# %%
#!/usr/bin/env python3

import os
import json
import time
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

from pathlib import Path

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, mean_squared_error

from sklearn.ensemble import IsolationForest
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

from sklearn.neighbors import LocalOutlierFactor

from sklearn.neural_network import MLPClassifier, MLPRegressor

from xgboost import XGBClassifier, XGBRegressor


########################################
# CONFIG
########################################

DATA_PATH="data"

DATASETS=[
"Bank_Customer_Churn_Dataset",
"cmc",
"connect-4",
"credit-g",
"electricity",
"elevators",
"eucalyptus",
"eye_movements",
"house_16H",
"kc1",
"phoneme",
"pol",
"socmob",
"splice",
"vehicle",

"california_housing",
"cpu_act",
"Bike_Sharing_Demand",
"abalone",
"wine_quality"
]

MODELS=[
"mlp",
"xgboost",
"randomforest"
]

OUTLIERS=[
None,
"ZScore",
"Percentile",
"IsolationForest",
"LOF",
"Autoencoder"
]

TREATMENTS=[
"remove",
"clip"
]

RUNS=5

CONTAMINATION=0.05

LOW_PCTL=5
HIGH_PCTL=95


########################################
# LOGGING
########################################

def log_text(msg):

    t=time.strftime("%Y-%m-%d %H:%M:%S")

    line=f"[{t}] {msg}"

    print(line)

    with open("results/experiment_log.txt","a") as f:
        f.write(line+"\n")


def valid_combo(detector,treatment):

    if detector is None:
        return treatment=="remove"

    if detector in ["ZScore","Percentile"]:
        return True

    return treatment=="remove"


def experiment_done(dataset,model,detector,treatment):

    path="results/summary.csv"

    if not os.path.exists(path):
        return False

    df=pd.read_csv(path)

    # normalize detector values (retroactive safe)
    def norm(x):

        if pd.isna(x):
            return "None"

        x=str(x)

        if x.lower() in ["none","nan",""]:
            return "None"

        return x

    detector = norm(detector)

    df["detector"]=df["detector"].apply(norm)

    return ((df.dataset.astype(str)==str(dataset))&
            (df.model.astype(str)==str(model))&
            (df.detector==detector)&
            (df.treatment.astype(str)==str(treatment))).any()


def log_summary(dataset,model,detector,treatment,res):

    path="results/summary.csv"

    if not os.path.exists(path):

        with open(path,"w") as f:

            f.write(
            "dataset,model,detector,treatment,"
            "mean,std,train_size,"
            "removed,removed_pct,"
            "clipped_values,clipped_rows,clipped_pct,"
            "outlier_pct,time\n"
            )

    with open(path,"a") as f:

        f.write(

        f"{dataset},{model},{detector},{treatment},"

        f"{res['mean']:.6f},"

        f"{res['std']:.6f},"

        f"{res['train_size']},"

        f"{res['removed']:.2f},"

        f"{res['removed_pct']:.6f},"

        f"{res['clipped']:.2f},"

        f"{res['clipped_rows']:.2f},"

        f"{res['clipped_pct']:.6f},"

        f"{res['outlier_pct']:.6f},"

        f"{res['time']:.3f}\n"

        )


########################################
# DATA
########################################

def load_json(path):

    return json.loads(Path(path).read_text())


def load_dataset(dataset):

    base=Path(DATA_PATH)/dataset

    def block(name):

        return {
            x:np.load(
                base/f"{name}_{x}.npy",
                allow_pickle=True
            )
            for x in ["train","val","test"]
        }

    N=block("N") if (base/"N_train.npy").exists() else None

    C=block("C") if (base/"C_train.npy").exists() else None

    y=block("y")

    info=load_json(base/"info.json")

    return N,C,y,info


########################################
# PREPROCESS
########################################

def preprocess_train(X):

    X=pd.DataFrame(X)

    numeric=X.select_dtypes(include=[np.number]).columns

    means={}
    stds={}

    for col in numeric:

        m=X[col].mean()

        X[col]=X[col].fillna(m)

        s=X[col].std()

        if s==0:
            s=1

        X[col]=(X[col]-m)/s

        means[col]=m
        stds[col]=s

    X=X.fillna(0).infer_objects(copy=False)

    return X.values,means,stds


def preprocess_test(X,means,stds):

    X=pd.DataFrame(X)

    for col in means:

        if col in X:

            X[col]=X[col].fillna(means[col])

            X[col]=(X[col]-means[col])/stds[col]

    X=X.fillna(0).infer_objects(copy=False)

    return X.values


########################################
# AUTOENCODER
########################################

class AE(nn.Module):

    def __init__(self,d):

        super().__init__()

        self.encoder=nn.Sequential(

            nn.Linear(d,64),
            nn.ReLU(),
            nn.Linear(64,16)
        )

        self.decoder=nn.Sequential(

            nn.Linear(16,64),
            nn.ReLU(),
            nn.Linear(64,d)
        )

    def forward(self,x):

        return self.decoder(self.encoder(x))


def ae_outliers(X,seed):

    torch.manual_seed(seed)

    X=torch.tensor(X,dtype=torch.float32)

    d=X.shape[1]

    model=AE(d)

    opt=torch.optim.Adam(model.parameters(),lr=0.001)

    loss_fn=nn.MSELoss()

    for _ in range(20):

        out=model(X)

        loss=loss_fn(out,X)

        opt.zero_grad()

        loss.backward()

        opt.step()

    with torch.no_grad():

        recon=model(X)

        err=((X-recon)**2).mean(1).numpy()

    thresh=np.percentile(err,100*(1-CONTAMINATION))

    mask=err<thresh

    return mask,None,None


########################################
# OUTLIERS
########################################

def detect_outliers(X,method,seed):

    X=np.asarray(X)

    if X.dtype==object:

        X=pd.DataFrame(X).apply(
            pd.to_numeric,
            errors="coerce"
        ).values

    X=np.nan_to_num(X)

    X=X.astype(np.float64)

    if method is None:
        return np.ones(len(X),bool),None,None


    if method=="ZScore":

        mean=X.mean(0)

        std=X.std(0)

        std[std==0]=1

        z=np.abs((X-mean)/std)

        mask=(z<3).all(1)

        lower=mean-3*std

        upper=mean+3*std

        return mask,lower,upper


    if method=="Percentile":

        lower=np.percentile(X,LOW_PCTL,axis=0)

        upper=np.percentile(X,HIGH_PCTL,axis=0)

        mask=((X>=lower)&(X<=upper)).all(1)

        return mask,lower,upper


    if method=="IsolationForest":

        clf=IsolationForest(
            contamination=CONTAMINATION,
            random_state=seed,
            n_estimators=200
        )

        mask=clf.fit_predict(X)==1

        return mask,None,None


    if method=="LOF":

        clf=LocalOutlierFactor(
            contamination=CONTAMINATION
        )

        mask=clf.fit_predict(X)==1

        return mask,None,None


    if method=="Autoencoder":

        return ae_outliers(X,seed)


########################################
# CLIP
########################################

def clip_numeric(X,lower,upper):

    if lower is None:
        return X,0,0

    original_X=X.copy()

    clipped_values=0

    for i in range(X.shape[1]):

        before=X[:,i].copy()

        X[:,i]=np.clip(
            X[:,i],
            lower[i],
            upper[i]
        )

        clipped_values+=np.sum(before!=X[:,i])

    clipped_rows=np.sum(
        np.any(original_X!=X,axis=1)
    )

    return X,clipped_values,clipped_rows


########################################
# MODELS
########################################

def make_model(name,task,seed):

    if name=="mlp":

        if task=="classification":

            return MLPClassifier(
                hidden_layer_sizes=(100,),
                max_iter=500,
                random_state=seed
            )

        return MLPRegressor(
            hidden_layer_sizes=(100,),
            max_iter=500,
            random_state=seed
        )


    if name=="xgboost":

        if task=="classification":

            return XGBClassifier(
                eval_metric="logloss",
                random_state=seed,
                n_estimators=200,
                tree_method="hist"
            )

        return XGBRegressor(
            random_state=seed,
            n_estimators=200,
            tree_method="hist"
        )


    if name=="randomforest":

        if task=="classification":

            return RandomForestClassifier(
                n_estimators=200,
                random_state=seed
            )

        return RandomForestRegressor(
            n_estimators=100,
            random_state=seed
        )


########################################
# SINGLE RUN
########################################

def single_run(dataset,model,detector,treatment,seed):

    np.random.seed(seed)
    random.seed(seed)

    N,C,y,info=load_dataset(dataset)

    y_train=y["train"].ravel()
    y_test=y["test"].ravel()

    idx=np.random.choice(len(y_train),len(y_train),replace=True)

    y_train=y_train[idx]

    if N is not None:
        N["train"]=N["train"][idx]

    if C is not None:
        C["train"]=C["train"][idx]

    before=len(y_train)

    if N is not None:

        mask,lower,upper=detect_outliers(
            N["train"],
            detector,
            seed
        )

    else:

        mask=np.ones(before,bool)
        lower=None
        upper=None

    clipped=0
    clipped_rows=0

    if treatment=="remove":

        if N is not None:
            N["train"]=N["train"][mask]

        if C is not None:
            C["train"]=C["train"][mask]

        y_train=y_train[mask]


    if treatment=="clip" and N is not None:

        N["train"],clipped,clipped_rows=clip_numeric(
            N["train"],
            lower,
            upper
        )


    after=len(y_train)

    removed=before-after

    removed_pct=removed/before if before>0 else 0

    clipped_pct=clipped_rows/before if before>0 else 0

    outlier_pct=removed_pct if treatment=="remove" else clipped_pct

    train_size=after


    if N is not None and C is not None:

        X_train=np.hstack([N["train"],C["train"]])
        X_test=np.hstack([N["test"],C["test"]])

    elif N is not None:

        X_train=N["train"]
        X_test=N["test"]

    else:

        X_train=C["train"]
        X_test=C["test"]


    X_train=pd.DataFrame(X_train)
    X_test=pd.DataFrame(X_test)


    for col in X_train.columns:

        if X_train[col].dtype==object:

            le=LabelEncoder()

            X_train[col]=le.fit_transform(
                X_train[col].astype(str)
            )

            X_test[col]=X_test[col].astype(str)

            X_test[col]=X_test[col].map(

                lambda x:
                le.transform([x])[0]
                if x in le.classes_
                else 0
            )


    X_train,means,stds=preprocess_train(X_train)

    X_test=preprocess_test(X_test,means,stds)


    task=info["task_type"]

    if task!="regression":
        task="classification"


    if task=="classification":

        le=LabelEncoder()

        le.fit(y_train)

        y_train=le.transform(y_train)

        y_test=np.array([

            le.transform([x])[0]

            if x in le.classes_

            else 0

            for x in y_test
        ])


    model=make_model(model,task,seed)

    start=time.time()

    model.fit(X_train,y_train)

    train_time=time.time()-start

    score=evaluate(model,X_test,y_test,task)


    return {

        "score":score,

        "removed":removed,
        "removed_pct":removed_pct,

        "clipped":clipped,
        "clipped_rows":clipped_rows,
        "clipped_pct":clipped_pct,

        "outlier_pct":outlier_pct,

        "train_size":train_size,

        "time":train_time
    }


########################################
# EVALUATE
########################################

def evaluate(model,X,y,task):

    pred=model.predict(X)

    if task=="classification":
        return accuracy_score(y,pred)

    return mean_squared_error(y,pred)


########################################
# EXPERIMENT
########################################

def run_experiment(dataset,model,detector,treatment):

    scores=[]
    removed=[]
    removed_pct=[]
    clipped=[]
    clipped_rows=[]
    clipped_pct=[]
    outlier_pct=[]
    times=[]
    train_sizes=[]

    for i in range(RUNS):

        seed=42+i

        r=single_run(dataset,model,detector,treatment,seed)

        scores.append(r["score"])

        removed.append(r["removed"])
        removed_pct.append(r["removed_pct"])

        clipped.append(r["clipped"])
        clipped_rows.append(r["clipped_rows"])
        clipped_pct.append(r["clipped_pct"])

        outlier_pct.append(r["outlier_pct"])

        times.append(r["time"])

        train_sizes.append(r["train_size"])


        log_text(

        f"{dataset} {model} "

        f"{detector} {treatment} "

        f"run={i} "

        f"score={r['score']:.5f} "

        f"outliers={r['outlier_pct']:.4f}"

        )


    scores=np.array(scores)

    return {

        "mean":scores.mean(),

        "std":scores.std(),

        "removed":np.mean(removed),

        "removed_pct":np.mean(removed_pct),

        "clipped":np.mean(clipped),

        "clipped_rows":np.mean(clipped_rows),

        "clipped_pct":np.mean(clipped_pct),

        "outlier_pct":np.mean(outlier_pct),

        "train_size":int(np.mean(train_sizes)),

        "time":np.mean(times)
    }


########################################
# MAIN
########################################

def main():

    os.makedirs("results",exist_ok=True)

    log_text("Experiment started")

    combos=[

        (d,m,o,t)

        for d in DATASETS

        for m in MODELS

        for o in OUTLIERS

        for t in TREATMENTS

        if valid_combo(o,t)
    ]

    total=len(combos)

    counter=0

    for dataset,model,detector,treatment in combos:

        counter+=1

        label=f"{dataset} {model} {detector} {treatment}"

        if experiment_done(dataset,model,detector,treatment):

            log_text(f"SKIP {counter}/{total} {label}")

            continue

        try:

            log_text(f"RUN {counter}/{total} {label}")

            res=run_experiment(

                dataset,
                model,
                detector,
                treatment
            )

            log_text(

            f"RESULT {label} "

            f"{res['mean']:.4f} "

            f"outliers={res['outlier_pct']:.4f}"

            )

            log_summary(
                dataset,
                model,
                detector,
                treatment,
                res
            )

        except Exception as e:

            log_text(f"FAILED {label}")

            log_text(str(e))

            continue


    log_text("Experiment finished")


if __name__=="__main__":

    main()
# Out:
# [2026-03-20 13:58:49] Experiment started
# [2026-03-20 13:58:49] SKIP 1/360 Bank_Customer_Churn_Dataset mlp None remove
# [2026-03-20 13:58:49] SKIP 2/360 Bank_Customer_Churn_Dataset mlp ZScore remove
# [2026-03-20 13:58:49] SKIP 3/360 Bank_Customer_Churn_Dataset mlp ZScore clip
# [2026-03-20 13:58:49] SKIP 4/360 Bank_Customer_Churn_Dataset mlp Percentile remove
# [2026-03-20 13:58:49] SKIP 5/360 Bank_Customer_Churn_Dataset mlp Percentile clip
# [2026-03-20 13:58:49] SKIP 6/360 Bank_Customer_Churn_Dataset mlp IsolationForest remove
# [2026-03-20 13:58:49] SKIP 7/360 Bank_Customer_Churn_Dataset mlp LOF remove
# [2026-03-20 13:58:49] SKIP 8/360 Bank_Customer_Churn_Dataset mlp Autoencoder remove
# [2026-03-20 13:58:49] SKIP 9/360 Bank_Customer_Churn_Dataset xgboost None remove
# [2026-03-20 13:58:49] SKIP 10/360 Bank_Customer_Churn_Dataset xgboost ZScore remove
# [2026-03-20 13:58:49] SKIP 11/360 Bank_Customer_Churn_Dataset xgboost ZScore clip
# [2026-03-20 13:58:49] SKIP 12/360 Bank_Customer_Churn_Dataset xgboost Percentile remove
# [2026-03-20 13:58:49] SKIP 13/360 Bank_Customer_Churn_Dataset xgboost Percentile clip
# [2026-03-20 13:58:49] SKIP 14/360 Bank_Customer_Churn_Dataset xgboost IsolationForest remove
# [2026-03-20 13:58:49] SKIP 15/360 Bank_Customer_Churn_Dataset xgboost LOF remove
# [2026-03-20 13:58:49] SKIP 16/360 Bank_Customer_Churn_Dataset xgboost Autoencoder remove
# [2026-03-20 13:58:49] SKIP 17/360 Bank_Customer_Churn_Dataset randomforest None remove
# [2026-03-20 13:58:49] SKIP 18/360 Bank_Customer_Churn_Dataset randomforest ZScore remove
# [2026-03-20 13:58:49] SKIP 19/360 Bank_Customer_Churn_Dataset randomforest ZScore clip
# [2026-03-20 13:58:49] SKIP 20/360 Bank_Customer_Churn_Dataset randomforest Percentile remove
# [2026-03-20 13:58:49] SKIP 21/360 Bank_Customer_Churn_Dataset randomforest Percentile clip
# [2026-03-20 13:58:49] SKIP 22/360 Bank_Customer_Churn_Dataset randomforest IsolationForest remove
# [2026-03-20 13:58:49] SKIP 23/360 Bank_Customer_Churn_Dataset randomforest LOF remove
# [2026-03-20 13:58:49] SKIP 24/360 Bank_Customer_Churn_Dataset randomforest Autoencoder remove
# [2026-03-20 13:58:49] SKIP 25/360 cmc mlp None remove
# [2026-03-20 13:58:49] SKIP 26/360 cmc mlp ZScore remove
# [2026-03-20 13:58:49] SKIP 27/360 cmc mlp ZScore clip
# [2026-03-20 13:58:49] SKIP 28/360 cmc mlp Percentile remove
# [2026-03-20 13:58:49] SKIP 29/360 cmc mlp Percentile clip
# [2026-03-20 13:58:49] SKIP 30/360 cmc mlp IsolationForest remove
# [2026-03-20 13:58:49] SKIP 31/360 cmc mlp LOF remove
# [2026-03-20 13:58:49] SKIP 32/360 cmc mlp Autoencoder remove
# [2026-03-20 13:58:49] SKIP 33/360 cmc xgboost None remove
# [2026-03-20 13:58:49] SKIP 34/360 cmc xgboost ZScore remove
# [2026-03-20 13:58:49] SKIP 35/360 cmc xgboost ZScore clip
# [2026-03-20 13:58:49] SKIP 36/360 cmc xgboost Percentile remove
# [2026-03-20 13:58:49] SKIP 37/360 cmc xgboost Percentile clip
# [2026-03-20 13:58:49] SKIP 38/360 cmc xgboost IsolationForest remove
# [2026-03-20 13:58:49] SKIP 39/360 cmc xgboost LOF remove
# [2026-03-20 13:58:49] SKIP 40/360 cmc xgboost Autoencoder remove
# [2026-03-20 13:58:49] SKIP 41/360 cmc randomforest None remove
# [2026-03-20 13:58:49] SKIP 42/360 cmc randomforest ZScore remove
# [2026-03-20 13:58:49] SKIP 43/360 cmc randomforest ZScore clip
# [2026-03-20 13:58:49] SKIP 44/360 cmc randomforest Percentile remove
# [2026-03-20 13:58:49] SKIP 45/360 cmc randomforest Percentile clip
# [2026-03-20 13:58:49] SKIP 46/360 cmc randomforest IsolationForest remove
# [2026-03-20 13:58:49] SKIP 47/360 cmc randomforest LOF remove
# [2026-03-20 13:58:49] SKIP 48/360 cmc randomforest Autoencoder remove
# [2026-03-20 13:58:49] SKIP 49/360 connect-4 mlp None remove
# [2026-03-20 13:58:49] SKIP 50/360 connect-4 mlp ZScore remove
# [2026-03-20 13:58:49] SKIP 51/360 connect-4 mlp ZScore clip
# [2026-03-20 13:58:49] SKIP 52/360 connect-4 mlp Percentile remove
# [2026-03-20 13:58:49] SKIP 53/360 connect-4 mlp Percentile clip
# [2026-03-20 13:58:49] SKIP 54/360 connect-4 mlp IsolationForest remove
# [2026-03-20 13:58:49] SKIP 55/360 connect-4 mlp LOF remove
# [2026-03-20 13:58:49] SKIP 56/360 connect-4 mlp Autoencoder remove
# [2026-03-20 13:58:49] SKIP 57/360 connect-4 xgboost None remove
# [2026-03-20 13:58:49] SKIP 58/360 connect-4 xgboost ZScore remove
# [2026-03-20 13:58:49] SKIP 59/360 connect-4 xgboost ZScore clip
# [2026-03-20 13:58:49] SKIP 60/360 connect-4 xgboost Percentile remove
# [2026-03-20 13:58:49] SKIP 61/360 connect-4 xgboost Percentile clip
# [2026-03-20 13:58:49] SKIP 62/360 connect-4 xgboost IsolationForest remove
# [2026-03-20 13:58:49] SKIP 63/360 connect-4 xgboost LOF remove
# [2026-03-20 13:58:49] SKIP 64/360 connect-4 xgboost Autoencoder remove
# [2026-03-20 13:58:49] SKIP 65/360 connect-4 randomforest None remove
# [2026-03-20 13:58:49] SKIP 66/360 connect-4 randomforest ZScore remove
# [2026-03-20 13:58:49] SKIP 67/360 connect-4 randomforest ZScore clip
# [2026-03-20 13:58:49] SKIP 68/360 connect-4 randomforest Percentile remove
# [2026-03-20 13:58:49] SKIP 69/360 connect-4 randomforest Percentile clip
# [2026-03-20 13:58:49] SKIP 70/360 connect-4 randomforest IsolationForest remove
# [2026-03-20 13:58:49] SKIP 71/360 connect-4 randomforest LOF remove
# [2026-03-20 13:58:49] SKIP 72/360 connect-4 randomforest Autoencoder remove
# [2026-03-20 13:58:49] SKIP 73/360 credit-g mlp None remove
# [2026-03-20 13:58:49] SKIP 74/360 credit-g mlp ZScore remove
# [2026-03-20 13:58:49] SKIP 75/360 credit-g mlp ZScore clip
# [2026-03-20 13:58:49] SKIP 76/360 credit-g mlp Percentile remove
# [2026-03-20 13:58:49] SKIP 77/360 credit-g mlp Percentile clip
# [2026-03-20 13:58:49] SKIP 78/360 credit-g mlp IsolationForest remove
# [2026-03-20 13:58:49] SKIP 79/360 credit-g mlp LOF remove
# [2026-03-20 13:58:49] SKIP 80/360 credit-g mlp Autoencoder remove
# [2026-03-20 13:58:49] SKIP 81/360 credit-g xgboost None remove
# [2026-03-20 13:58:49] SKIP 82/360 credit-g xgboost ZScore remove
# [2026-03-20 13:58:49] SKIP 83/360 credit-g xgboost ZScore clip
# [2026-03-20 13:58:49] SKIP 84/360 credit-g xgboost Percentile remove
# [2026-03-20 13:58:49] SKIP 85/360 credit-g xgboost Percentile clip
# [2026-03-20 13:58:49] SKIP 86/360 credit-g xgboost IsolationForest remove
# [2026-03-20 13:58:49] SKIP 87/360 credit-g xgboost LOF remove
# [2026-03-20 13:58:49] SKIP 88/360 credit-g xgboost Autoencoder remove
# [2026-03-20 13:58:49] SKIP 89/360 credit-g randomforest None remove
# [2026-03-20 13:58:49] SKIP 90/360 credit-g randomforest ZScore remove
# [2026-03-20 13:58:49] SKIP 91/360 credit-g randomforest ZScore clip
# [2026-03-20 13:58:49] SKIP 92/360 credit-g randomforest Percentile remove
# [2026-03-20 13:58:49] SKIP 93/360 credit-g randomforest Percentile clip
# [2026-03-20 13:58:49] SKIP 94/360 credit-g randomforest IsolationForest remove
# [2026-03-20 13:58:49] SKIP 95/360 credit-g randomforest LOF remove
# [2026-03-20 13:58:49] SKIP 96/360 credit-g randomforest Autoencoder remove
# [2026-03-20 13:58:49] SKIP 97/360 electricity mlp None remove
# [2026-03-20 13:58:49] SKIP 98/360 electricity mlp ZScore remove
# [2026-03-20 13:58:49] SKIP 99/360 electricity mlp ZScore clip
# [2026-03-20 13:58:49] SKIP 100/360 electricity mlp Percentile remove
# [2026-03-20 13:58:49] SKIP 101/360 electricity mlp Percentile clip
# [2026-03-20 13:58:49] SKIP 102/360 electricity mlp IsolationForest remove
# [2026-03-20 13:58:49] SKIP 103/360 electricity mlp LOF remove
# [2026-03-20 13:58:49] SKIP 104/360 electricity mlp Autoencoder remove
# [2026-03-20 13:58:49] RUN 105/360 electricity xgboost None remove
# [2026-03-20 13:59:52] electricity xgboost None remove run=0 score=0.86263 outliers=0.0000
# [2026-03-20 14:00:54] electricity xgboost None remove run=1 score=0.86285 outliers=0.0000
# [2026-03-20 14:01:54] electricity xgboost None remove run=2 score=0.86528 outliers=0.0000
# [2026-03-20 14:02:51] electricity xgboost None remove run=3 score=0.86759 outliers=0.0000
# [2026-03-20 14:03:50] electricity xgboost None remove run=4 score=0.85888 outliers=0.0000
# [2026-03-20 14:03:50] RESULT electricity xgboost None remove 0.8634 outliers=0.0000
# [2026-03-20 14:03:50] RUN 106/360 electricity xgboost ZScore remove
# [2026-03-20 14:04:53] electricity xgboost ZScore remove run=0 score=0.85910 outliers=0.0118
# [2026-03-20 14:05:55] electricity xgboost ZScore remove run=1 score=0.86406 outliers=0.0112
# [2026-03-20 14:06:54] electricity xgboost ZScore remove run=2 score=0.86384 outliers=0.0115
# [2026-03-20 14:07:56] electricity xgboost ZScore remove run=3 score=0.86197 outliers=0.0122
# [2026-03-20 14:08:59] electricity xgboost ZScore remove run=4 score=0.85888 outliers=0.0126
# [2026-03-20 14:08:59] RESULT electricity xgboost ZScore remove 0.8616 outliers=0.0119
# [2026-03-20 14:08:59] RUN 107/360 electricity xgboost ZScore clip
# [2026-03-20 14:10:02] electricity xgboost ZScore clip run=0 score=0.86373 outliers=0.0118
# [2026-03-20 14:11:05] electricity xgboost ZScore clip run=1 score=0.86737 outliers=0.0112
# [2026-03-20 14:12:05] electricity xgboost ZScore clip run=2 score=0.86340 outliers=0.0115
# [2026-03-20 14:13:09] electricity xgboost ZScore clip run=3 score=0.86472 outliers=0.0122
# [2026-03-20 14:14:12] electricity xgboost ZScore clip run=4 score=0.85777 outliers=0.0126
# [2026-03-20 14:14:12] RESULT electricity xgboost ZScore clip 0.8634 outliers=0.0119
# [2026-03-20 14:14:12] RUN 108/360 electricity xgboost Percentile remove
# [2026-03-20 14:14:49] electricity xgboost Percentile remove run=0 score=0.77623 outliers=0.4493
# [2026-03-20 14:15:27] electricity xgboost Percentile remove run=1 score=0.77347 outliers=0.4471
# [2026-03-20 14:16:04] electricity xgboost Percentile remove run=2 score=0.77701 outliers=0.4492
# [2026-03-20 14:16:42] electricity xgboost Percentile remove run=3 score=0.78120 outliers=0.4494
# [2026-03-20 14:17:23] electricity xgboost Percentile remove run=4 score=0.76950 outliers=0.4512
# [2026-03-20 14:17:23] RESULT electricity xgboost Percentile remove 0.7755 outliers=0.4492
# [2026-03-20 14:17:23] RUN 109/360 electricity xgboost Percentile clip
# [2026-03-20 14:18:05] electricity xgboost Percentile clip run=0 score=0.81209 outliers=0.4493
# [2026-03-20 14:18:47] electricity xgboost Percentile clip run=1 score=0.82202 outliers=0.4471
# [2026-03-20 14:19:30] electricity xgboost Percentile clip run=2 score=0.82191 outliers=0.4492
# [2026-03-20 14:20:12] electricity xgboost Percentile clip run=3 score=0.81794 outliers=0.4494
# [2026-03-20 14:20:57] electricity xgboost Percentile clip run=4 score=0.81364 outliers=0.4512
# [2026-03-20 14:20:57] RESULT electricity xgboost Percentile clip 0.8175 outliers=0.4492
# [2026-03-20 14:20:57] RUN 110/360 electricity xgboost IsolationForest remove
# [2026-03-20 14:21:54] electricity xgboost IsolationForest remove run=0 score=0.84961 outliers=0.0500
# [2026-03-20 14:22:54] electricity xgboost IsolationForest remove run=1 score=0.85866 outliers=0.0500
# [2026-03-20 14:23:54] electricity xgboost IsolationForest remove run=2 score=0.85855 outliers=0.0500
# [2026-03-20 14:24:55] electricity xgboost IsolationForest remove run=3 score=0.85766 outliers=0.0500
# [2026-03-20 14:25:52] electricity xgboost IsolationForest remove run=4 score=0.85226 outliers=0.0500
# [2026-03-20 14:25:52] RESULT electricity xgboost IsolationForest remove 0.8553 outliers=0.0500
# [2026-03-20 14:25:52] RUN 111/360 electricity xgboost LOF remove
# [2026-03-20 14:26:56] electricity xgboost LOF remove run=0 score=0.85546 outliers=0.0500
# [2026-03-20 14:28:00] electricity xgboost LOF remove run=1 score=0.85678 outliers=0.0500
# [2026-03-20 14:29:04] electricity xgboost LOF remove run=2 score=0.85601 outliers=0.0500
# [2026-03-20 14:30:08] electricity xgboost LOF remove run=3 score=0.85634 outliers=0.0500
# [2026-03-20 14:31:11] electricity xgboost LOF remove run=4 score=0.85755 outliers=0.0500
# [2026-03-20 14:31:11] RESULT electricity xgboost LOF remove 0.8564 outliers=0.0500
# [2026-03-20 14:31:11] RUN 112/360 electricity xgboost Autoencoder remove
# [2026-03-20 14:32:23] electricity xgboost Autoencoder remove run=0 score=0.85733 outliers=0.0500
# [2026-03-20 14:33:29] electricity xgboost Autoencoder remove run=1 score=0.86009 outliers=0.0501
# [2026-03-20 14:34:34] electricity xgboost Autoencoder remove run=2 score=0.85821 outliers=0.0500
# [2026-03-20 14:35:40] electricity xgboost Autoencoder remove run=3 score=0.86495 outliers=0.0500
# [2026-03-20 14:36:46] electricity xgboost Autoencoder remove run=4 score=0.85744 outliers=0.0500
# [2026-03-20 14:36:46] RESULT electricity xgboost Autoencoder remove 0.8596 outliers=0.0500
# [2026-03-20 14:36:46] RUN 113/360 electricity randomforest None remove
# [2026-03-20 14:37:57] electricity randomforest None remove run=0 score=0.84917 outliers=0.0000
# [2026-03-20 14:39:08] electricity randomforest None remove run=1 score=0.85126 outliers=0.0000
# [2026-03-20 14:40:26] electricity randomforest None remove run=2 score=0.85248 outliers=0.0000
# [2026-03-20 14:41:43] electricity randomforest None remove run=3 score=0.85524 outliers=0.0000
# [2026-03-20 14:42:52] electricity randomforest None remove run=4 score=0.85170 outliers=0.0000
# [2026-03-20 14:42:52] RESULT electricity randomforest None remove 0.8520 outliers=0.0000
# [2026-03-20 14:42:52] RUN 114/360 electricity randomforest ZScore remove
# [2026-03-20 14:44:04] electricity randomforest ZScore remove run=0 score=0.85060 outliers=0.0118
# [2026-03-20 14:45:18] electricity randomforest ZScore remove run=1 score=0.85038 outliers=0.0112
# [2026-03-20 14:46:31] electricity randomforest ZScore remove run=2 score=0.85093 outliers=0.0115
# [2026-03-20 14:47:45] electricity randomforest ZScore remove run=3 score=0.85568 outliers=0.0122
# [2026-03-20 14:48:54] electricity randomforest ZScore remove run=4 score=0.85071 outliers=0.0126
# [2026-03-20 14:48:54] RESULT electricity randomforest ZScore remove 0.8517 outliers=0.0119
# [2026-03-20 14:48:54] RUN 115/360 electricity randomforest ZScore clip
# [2026-03-20 14:50:04] electricity randomforest ZScore clip run=0 score=0.84729 outliers=0.0118
# [2026-03-20 14:51:22] electricity randomforest ZScore clip run=1 score=0.85049 outliers=0.0112
# [2026-03-20 14:52:38] electricity randomforest ZScore clip run=2 score=0.85027 outliers=0.0115
# [2026-03-20 14:53:50] electricity randomforest ZScore clip run=3 score=0.85270 outliers=0.0122
# [2026-03-20 14:55:04] electricity randomforest ZScore clip run=4 score=0.84983 outliers=0.0126
# [2026-03-20 14:55:04] RESULT electricity randomforest ZScore clip 0.8501 outliers=0.0119
# [2026-03-20 14:55:04] RUN 116/360 electricity randomforest Percentile remove
# [2026-03-20 14:55:43] electricity randomforest Percentile remove run=0 score=0.76917 outliers=0.4493
# [2026-03-20 14:56:25] electricity randomforest Percentile remove run=1 score=0.77105 outliers=0.4471
# [2026-03-20 14:57:02] electricity randomforest Percentile remove run=2 score=0.76399 outliers=0.4492
# [2026-03-20 14:57:40] electricity randomforest Percentile remove run=3 score=0.76730 outliers=0.4494
# [2026-03-20 14:58:21] electricity randomforest Percentile remove run=4 score=0.76211 outliers=0.4512
# [2026-03-20 14:58:21] RESULT electricity randomforest Percentile remove 0.7667 outliers=0.4492
# [2026-03-20 14:58:21] RUN 117/360 electricity randomforest Percentile clip
# [2026-03-20 14:59:06] electricity randomforest Percentile clip run=0 score=0.80260 outliers=0.4493
# [2026-03-20 14:59:51] electricity randomforest Percentile clip run=1 score=0.80558 outliers=0.4471
# [2026-03-20 15:00:39] electricity randomforest Percentile clip run=2 score=0.80282 outliers=0.4492
# [2026-03-20 15:01:56] electricity randomforest Percentile clip run=3 score=0.80680 outliers=0.4494
# [2026-03-20 15:02:46] electricity randomforest Percentile clip run=4 score=0.80547 outliers=0.4512
# [2026-03-20 15:02:46] RESULT electricity randomforest Percentile clip 0.8047 outliers=0.4492
# [2026-03-20 15:02:46] RUN 118/360 electricity randomforest IsolationForest remove
# [2026-03-20 15:03:48] electricity randomforest IsolationForest remove run=0 score=0.84056 outliers=0.0500
# [2026-03-20 15:04:52] electricity randomforest IsolationForest remove run=1 score=0.84420 outliers=0.0500
# [2026-03-20 15:05:56] electricity randomforest IsolationForest remove run=2 score=0.84597 outliers=0.0500
# [2026-03-20 15:07:02] electricity randomforest IsolationForest remove run=3 score=0.84784 outliers=0.0500
# [2026-03-20 15:08:07] electricity randomforest IsolationForest remove run=4 score=0.83979 outliers=0.0500
# [2026-03-20 15:08:07] RESULT electricity randomforest IsolationForest remove 0.8437 outliers=0.0500
# [2026-03-20 15:08:07] RUN 119/360 electricity randomforest LOF remove
# [2026-03-20 15:09:14] electricity randomforest LOF remove run=0 score=0.84133 outliers=0.0500
# [2026-03-20 15:10:23] electricity randomforest LOF remove run=1 score=0.84685 outliers=0.0500
# [2026-03-20 15:11:31] electricity randomforest LOF remove run=2 score=0.84542 outliers=0.0500
# [2026-03-20 15:12:40] electricity randomforest LOF remove run=3 score=0.84917 outliers=0.0500
# [2026-03-20 15:13:48] electricity randomforest LOF remove run=4 score=0.84497 outliers=0.0500
# [2026-03-20 15:13:48] RESULT electricity randomforest LOF remove 0.8455 outliers=0.0500
# [2026-03-20 15:13:48] RUN 120/360 electricity randomforest Autoencoder remove
# [2026-03-20 15:14:55] electricity randomforest Autoencoder remove run=0 score=0.84078 outliers=0.0500
# [2026-03-20 15:16:00] electricity randomforest Autoencoder remove run=1 score=0.84508 outliers=0.0501
# [2026-03-20 15:17:08] electricity randomforest Autoencoder remove run=2 score=0.84442 outliers=0.0500
# [2026-03-20 15:18:17] electricity randomforest Autoencoder remove run=3 score=0.85060 outliers=0.0500
# [2026-03-20 15:19:27] electricity randomforest Autoencoder remove run=4 score=0.84464 outliers=0.0500
# [2026-03-20 15:19:27] RESULT electricity randomforest Autoencoder remove 0.8451 outliers=0.0500
# [2026-03-20 15:19:27] RUN 121/360 elevators mlp None remove
# [2026-03-20 15:19:28] elevators mlp None remove run=0 score=0.00057 outliers=0.0000
# [2026-03-20 15:19:28] elevators mlp None remove run=1 score=0.00067 outliers=0.0000
# [2026-03-20 15:19:29] elevators mlp None remove run=2 score=0.00117 outliers=0.0000
# [2026-03-20 15:19:32] elevators mlp None remove run=3 score=0.00101 outliers=0.0000
# [2026-03-20 15:19:32] elevators mlp None remove run=4 score=0.00120 outliers=0.0000
# [2026-03-20 15:19:32] RESULT elevators mlp None remove 0.0009 outliers=0.0000
# [2026-03-20 15:19:32] RUN 122/360 elevators mlp ZScore remove
# [2026-03-20 15:19:32] elevators mlp ZScore remove run=0 score=0.00140 outliers=0.1263
# [2026-03-20 15:19:33] elevators mlp ZScore remove run=1 score=0.00225 outliers=0.1225
# [2026-03-20 15:19:33] elevators mlp ZScore remove run=2 score=0.00150 outliers=0.1297
# [2026-03-20 15:19:33] elevators mlp ZScore remove run=3 score=0.00248 outliers=0.1212
# [2026-03-20 15:19:34] elevators mlp ZScore remove run=4 score=0.00147 outliers=0.1251
# [2026-03-20 15:19:34] RESULT elevators mlp ZScore remove 0.0018 outliers=0.1250
# [2026-03-20 15:19:34] RUN 123/360 elevators mlp ZScore clip
# [2026-03-20 15:19:34] elevators mlp ZScore clip run=0 score=0.00118 outliers=0.1263
# [2026-03-20 15:19:34] elevators mlp ZScore clip run=1 score=0.00173 outliers=0.1225
# [2026-03-20 15:19:35] elevators mlp ZScore clip run=2 score=0.00144 outliers=0.1297
# [2026-03-20 15:19:35] elevators mlp ZScore clip run=3 score=0.00088 outliers=0.1212
# [2026-03-20 15:19:36] elevators mlp ZScore clip run=4 score=0.00114 outliers=0.1251
# [2026-03-20 15:19:36] RESULT elevators mlp ZScore clip 0.0013 outliers=0.1250
# [2026-03-20 15:19:36] RUN 124/360 elevators mlp Percentile remove
# [2026-03-20 15:19:36] elevators mlp Percentile remove run=0 score=0.00414 outliers=0.5316
# [2026-03-20 15:19:36] elevators mlp Percentile remove run=1 score=0.00636 outliers=0.5217
# [2026-03-20 15:19:36] elevators mlp Percentile remove run=2 score=0.00501 outliers=0.5288
# [2026-03-20 15:19:37] elevators mlp Percentile remove run=3 score=0.18772 outliers=0.5283
# [2026-03-20 15:19:37] elevators mlp Percentile remove run=4 score=0.00448 outliers=0.5238
# [2026-03-20 15:19:37] RESULT elevators mlp Percentile remove 0.0415 outliers=0.5268
# [2026-03-20 15:19:37] RUN 125/360 elevators mlp Percentile clip
# [2026-03-20 15:19:37] elevators mlp Percentile clip run=0 score=0.00119 outliers=0.5316
# [2026-03-20 15:19:38] elevators mlp Percentile clip run=1 score=0.00198 outliers=0.5217
# [2026-03-20 15:19:38] elevators mlp Percentile clip run=2 score=0.00180 outliers=0.5288
# [2026-03-20 15:19:38] elevators mlp Percentile clip run=3 score=0.05803 outliers=0.5283
# [2026-03-20 15:19:39] elevators mlp Percentile clip run=4 score=0.00136 outliers=0.5238
# [2026-03-20 15:19:39] RESULT elevators mlp Percentile clip 0.0129 outliers=0.5268
# [2026-03-20 15:19:39] RUN 126/360 elevators mlp IsolationForest remove
# [2026-03-20 15:19:39] elevators mlp IsolationForest remove run=0 score=0.00125 outliers=0.0501
# [2026-03-20 15:19:40] elevators mlp IsolationForest remove run=1 score=0.00129 outliers=0.0500
# [2026-03-20 15:19:41] elevators mlp IsolationForest remove run=2 score=0.00141 outliers=0.0499
# [2026-03-20 15:19:42] elevators mlp IsolationForest remove run=3 score=0.00094 outliers=0.0500
# [2026-03-20 15:19:42] elevators mlp IsolationForest remove run=4 score=0.00101 outliers=0.0501
# [2026-03-20 15:19:42] RESULT elevators mlp IsolationForest remove 0.0012 outliers=0.0500
# [2026-03-20 15:19:42] RUN 127/360 elevators mlp LOF remove
# [2026-03-20 15:19:43] elevators mlp LOF remove run=0 score=0.00087 outliers=0.0501
# [2026-03-20 15:19:44] elevators mlp LOF remove run=1 score=0.00170 outliers=0.0501
# [2026-03-20 15:19:44] elevators mlp LOF remove run=2 score=0.00161 outliers=0.0501
# [2026-03-20 15:19:45] elevators mlp LOF remove run=3 score=0.00089 outliers=0.0500
# [2026-03-20 15:19:45] elevators mlp LOF remove run=4 score=0.00078 outliers=0.0500
# [2026-03-20 15:19:45] RESULT elevators mlp LOF remove 0.0012 outliers=0.0500
# [2026-03-20 15:19:45] RUN 128/360 elevators mlp Autoencoder remove
# [2026-03-20 15:19:46] elevators mlp Autoencoder remove run=0 score=0.00106 outliers=0.0501
# [2026-03-20 15:19:47] elevators mlp Autoencoder remove run=1 score=0.00138 outliers=0.0501
# [2026-03-20 15:19:47] elevators mlp Autoencoder remove run=2 score=0.00152 outliers=0.0501
# [2026-03-20 15:19:48] elevators mlp Autoencoder remove run=3 score=0.00210 outliers=0.0501
# [2026-03-20 15:19:49] elevators mlp Autoencoder remove run=4 score=0.00094 outliers=0.0504
# [2026-03-20 15:19:49] RESULT elevators mlp Autoencoder remove 0.0014 outliers=0.0501
# [2026-03-20 15:19:49] RUN 129/360 elevators xgboost None remove
# [2026-03-20 15:19:49] elevators xgboost None remove run=0 score=0.00001 outliers=0.0000
# [2026-03-20 15:19:49] elevators xgboost None remove run=1 score=0.00001 outliers=0.0000
# [2026-03-20 15:19:49] elevators xgboost None remove run=2 score=0.00001 outliers=0.0000
# [2026-03-20 15:19:49] elevators xgboost None remove run=3 score=0.00001 outliers=0.0000
# [2026-03-20 15:19:49] elevators xgboost None remove run=4 score=0.00001 outliers=0.0000
# [2026-03-20 15:19:49] RESULT elevators xgboost None remove 0.0000 outliers=0.0000
# [2026-03-20 15:19:49] RUN 130/360 elevators xgboost ZScore remove
# [2026-03-20 15:19:49] elevators xgboost ZScore remove run=0 score=0.00001 outliers=0.1263
# [2026-03-20 15:19:50] elevators xgboost ZScore remove run=1 score=0.00001 outliers=0.1225
# [2026-03-20 15:19:50] elevators xgboost ZScore remove run=2 score=0.00001 outliers=0.1297
# [2026-03-20 15:19:50] elevators xgboost ZScore remove run=3 score=0.00001 outliers=0.1212
# [2026-03-20 15:19:50] elevators xgboost ZScore remove run=4 score=0.00001 outliers=0.1251
# [2026-03-20 15:19:50] RESULT elevators xgboost ZScore remove 0.0000 outliers=0.1250
# [2026-03-20 15:19:50] RUN 131/360 elevators xgboost ZScore clip
# [2026-03-20 15:19:50] elevators xgboost ZScore clip run=0 score=0.00001 outliers=0.1263
# [2026-03-20 15:19:50] elevators xgboost ZScore clip run=1 score=0.00001 outliers=0.1225
# [2026-03-20 15:19:50] elevators xgboost ZScore clip run=2 score=0.00001 outliers=0.1297
# [2026-03-20 15:19:50] elevators xgboost ZScore clip run=3 score=0.00001 outliers=0.1212
# [2026-03-20 15:19:50] elevators xgboost ZScore clip run=4 score=0.00001 outliers=0.1251
# [2026-03-20 15:19:50] RESULT elevators xgboost ZScore clip 0.0000 outliers=0.1250
# [2026-03-20 15:19:50] RUN 132/360 elevators xgboost Percentile remove
# [2026-03-20 15:19:50] elevators xgboost Percentile remove run=0 score=0.00001 outliers=0.5316
# [2026-03-20 15:19:51] elevators xgboost Percentile remove run=1 score=0.00001 outliers=0.5217
# [2026-03-20 15:19:51] elevators xgboost Percentile remove run=2 score=0.00001 outliers=0.5288
# [2026-03-20 15:19:51] elevators xgboost Percentile remove run=3 score=0.00001 outliers=0.5283
# [2026-03-20 15:19:51] elevators xgboost Percentile remove run=4 score=0.00001 outliers=0.5238
# [2026-03-20 15:19:51] RESULT elevators xgboost Percentile remove 0.0000 outliers=0.5268
# [2026-03-20 15:19:51] RUN 133/360 elevators xgboost Percentile clip
# [2026-03-20 15:19:51] elevators xgboost Percentile clip run=0 score=0.00001 outliers=0.5316
# [2026-03-20 15:19:51] elevators xgboost Percentile clip run=1 score=0.00001 outliers=0.5217
# [2026-03-20 15:19:51] elevators xgboost Percentile clip run=2 score=0.00001 outliers=0.5288
# [2026-03-20 15:19:51] elevators xgboost Percentile clip run=3 score=0.00001 outliers=0.5283
# [2026-03-20 15:19:51] elevators xgboost Percentile clip run=4 score=0.00001 outliers=0.5238
# [2026-03-20 15:19:51] RESULT elevators xgboost Percentile clip 0.0000 outliers=0.5268
# [2026-03-20 15:19:51] RUN 134/360 elevators xgboost IsolationForest remove
# [2026-03-20 15:19:52] elevators xgboost IsolationForest remove run=0 score=0.00001 outliers=0.0501
# [2026-03-20 15:19:52] elevators xgboost IsolationForest remove run=1 score=0.00001 outliers=0.0500
# [2026-03-20 15:19:53] elevators xgboost IsolationForest remove run=2 score=0.00001 outliers=0.0499
# [2026-03-20 15:19:53] elevators xgboost IsolationForest remove run=3 score=0.00001 outliers=0.0500
# [2026-03-20 15:19:54] elevators xgboost IsolationForest remove run=4 score=0.00001 outliers=0.0501
# [2026-03-20 15:19:54] RESULT elevators xgboost IsolationForest remove 0.0000 outliers=0.0500
# [2026-03-20 15:19:54] RUN 135/360 elevators xgboost LOF remove
# [2026-03-20 15:19:54] elevators xgboost LOF remove run=0 score=0.00001 outliers=0.0501
# [2026-03-20 15:19:54] elevators xgboost LOF remove run=1 score=0.00001 outliers=0.0501
# [2026-03-20 15:19:54] elevators xgboost LOF remove run=2 score=0.00001 outliers=0.0501
# [2026-03-20 15:19:55] elevators xgboost LOF remove run=3 score=0.00001 outliers=0.0500
# [2026-03-20 15:19:55] elevators xgboost LOF remove run=4 score=0.00001 outliers=0.0500
# [2026-03-20 15:19:55] RESULT elevators xgboost LOF remove 0.0000 outliers=0.0500
# [2026-03-20 15:19:55] RUN 136/360 elevators xgboost Autoencoder remove
# [2026-03-20 15:19:55] elevators xgboost Autoencoder remove run=0 score=0.00001 outliers=0.0501
# [2026-03-20 15:19:56] elevators xgboost Autoencoder remove run=1 score=0.00001 outliers=0.0501
# [2026-03-20 15:19:56] elevators xgboost Autoencoder remove run=2 score=0.00001 outliers=0.0501
# [2026-03-20 15:19:56] elevators xgboost Autoencoder remove run=3 score=0.00001 outliers=0.0501
# [2026-03-20 15:19:57] elevators xgboost Autoencoder remove run=4 score=0.00001 outliers=0.0504
# [2026-03-20 15:19:57] RESULT elevators xgboost Autoencoder remove 0.0000 outliers=0.0501
# [2026-03-20 15:19:57] RUN 137/360 elevators randomforest None remove
# [2026-03-20 15:20:01] elevators randomforest None remove run=0 score=0.00001 outliers=0.0000
# [2026-03-20 15:20:08] elevators randomforest None remove run=1 score=0.00001 outliers=0.0000
# [2026-03-20 15:20:13] elevators randomforest None remove run=2 score=0.00001 outliers=0.0000
# [2026-03-20 15:20:17] elevators randomforest None remove run=3 score=0.00001 outliers=0.0000
# [2026-03-20 15:20:22] elevators randomforest None remove run=4 score=0.00001 outliers=0.0000
# [2026-03-20 15:20:22] RESULT elevators randomforest None remove 0.0000 outliers=0.0000
# [2026-03-20 15:20:22] RUN 138/360 elevators randomforest ZScore remove
# [2026-03-20 15:20:26] elevators randomforest ZScore remove run=0 score=0.00001 outliers=0.1263
# [2026-03-20 15:20:29] elevators randomforest ZScore remove run=1 score=0.00001 outliers=0.1225
# [2026-03-20 15:20:33] elevators randomforest ZScore remove run=2 score=0.00001 outliers=0.1297
# [2026-03-20 15:20:37] elevators randomforest ZScore remove run=3 score=0.00001 outliers=0.1212
# [2026-03-20 15:20:43] elevators randomforest ZScore remove run=4 score=0.00001 outliers=0.1251
# [2026-03-20 15:20:43] RESULT elevators randomforest ZScore remove 0.0000 outliers=0.1250
# [2026-03-20 15:20:43] RUN 139/360 elevators randomforest ZScore clip
# [2026-03-20 15:20:47] elevators randomforest ZScore clip run=0 score=0.00001 outliers=0.1263
# [2026-03-20 15:20:53] elevators randomforest ZScore clip run=1 score=0.00001 outliers=0.1225
# [2026-03-20 15:20:57] elevators randomforest ZScore clip run=2 score=0.00001 outliers=0.1297
# [2026-03-20 15:21:02] elevators randomforest ZScore clip run=3 score=0.00001 outliers=0.1212
# [2026-03-20 15:21:07] elevators randomforest ZScore clip run=4 score=0.00001 outliers=0.1251
# [2026-03-20 15:21:07] RESULT elevators randomforest ZScore clip 0.0000 outliers=0.1250
# [2026-03-20 15:21:07] RUN 140/360 elevators randomforest Percentile remove
# [2026-03-20 15:21:09] elevators randomforest Percentile remove run=0 score=0.00002 outliers=0.5316
# [2026-03-20 15:21:10] elevators randomforest Percentile remove run=1 score=0.00002 outliers=0.5217
# [2026-03-20 15:21:12] elevators randomforest Percentile remove run=2 score=0.00002 outliers=0.5288
# [2026-03-20 15:21:17] elevators randomforest Percentile remove run=3 score=0.00002 outliers=0.5283
# [2026-03-20 15:21:18] elevators randomforest Percentile remove run=4 score=0.00002 outliers=0.5238
# [2026-03-20 15:21:18] RESULT elevators randomforest Percentile remove 0.0000 outliers=0.5268
# [2026-03-20 15:21:18] RUN 141/360 elevators randomforest Percentile clip
# [2026-03-20 15:21:23] elevators randomforest Percentile clip run=0 score=0.00001 outliers=0.5316
# [2026-03-20 15:21:27] elevators randomforest Percentile clip run=1 score=0.00001 outliers=0.5217
# [2026-03-20 15:21:31] elevators randomforest Percentile clip run=2 score=0.00001 outliers=0.5288
# [2026-03-20 15:21:35] elevators randomforest Percentile clip run=3 score=0.00001 outliers=0.5283
# [2026-03-20 15:21:39] elevators randomforest Percentile clip run=4 score=0.00001 outliers=0.5238
# [2026-03-20 15:21:39] RESULT elevators randomforest Percentile clip 0.0000 outliers=0.5268
# [2026-03-20 15:21:39] RUN 142/360 elevators randomforest IsolationForest remove
# [2026-03-20 15:21:43] elevators randomforest IsolationForest remove run=0 score=0.00001 outliers=0.0501
# [2026-03-20 15:21:50] elevators randomforest IsolationForest remove run=1 score=0.00001 outliers=0.0500
# [2026-03-20 15:21:55] elevators randomforest IsolationForest remove run=2 score=0.00001 outliers=0.0499
# [2026-03-20 15:21:59] elevators randomforest IsolationForest remove run=3 score=0.00001 outliers=0.0500
# [2026-03-20 15:22:04] elevators randomforest IsolationForest remove run=4 score=0.00001 outliers=0.0501
# [2026-03-20 15:22:04] RESULT elevators randomforest IsolationForest remove 0.0000 outliers=0.0500
# [2026-03-20 15:22:04] RUN 143/360 elevators randomforest LOF remove
# [2026-03-20 15:22:08] elevators randomforest LOF remove run=0 score=0.00001 outliers=0.0501
# [2026-03-20 15:22:12] elevators randomforest LOF remove run=1 score=0.00001 outliers=0.0501
# [2026-03-20 15:22:17] elevators randomforest LOF remove run=2 score=0.00001 outliers=0.0501
# [2026-03-20 15:22:21] elevators randomforest LOF remove run=3 score=0.00001 outliers=0.0500
# [2026-03-20 15:22:28] elevators randomforest LOF remove run=4 score=0.00001 outliers=0.0500
# [2026-03-20 15:22:28] RESULT elevators randomforest LOF remove 0.0000 outliers=0.0500
# [2026-03-20 15:22:28] RUN 144/360 elevators randomforest Autoencoder remove
# [2026-03-20 15:22:33] elevators randomforest Autoencoder remove run=0 score=0.00001 outliers=0.0501
# [2026-03-20 15:22:38] elevators randomforest Autoencoder remove run=1 score=0.00001 outliers=0.0501
# [2026-03-20 15:22:43] elevators randomforest Autoencoder remove run=2 score=0.00001 outliers=0.0501
# [2026-03-20 15:22:47] elevators randomforest Autoencoder remove run=3 score=0.00001 outliers=0.0501
# [2026-03-20 15:22:52] elevators randomforest Autoencoder remove run=4 score=0.00001 outliers=0.0504
# [2026-03-20 15:22:52] RESULT elevators randomforest Autoencoder remove 0.0000 outliers=0.0501
# [2026-03-20 15:22:52] RUN 145/360 eucalyptus mlp None remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:22:52] eucalyptus mlp None remove run=0 score=0.55405 outliers=0.0000
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:22:53] eucalyptus mlp None remove run=1 score=0.54730 outliers=0.0000
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:22:54] eucalyptus mlp None remove run=2 score=0.56081 outliers=0.0000
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:22:54] eucalyptus mlp None remove run=3 score=0.51351 outliers=0.0000
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:22:55] eucalyptus mlp None remove run=4 score=0.52703 outliers=0.0000
# [2026-03-20 15:22:55] RESULT eucalyptus mlp None remove 0.5405 outliers=0.0000
# [2026-03-20 15:22:55] RUN 146/360 eucalyptus mlp ZScore remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:22:55] eucalyptus mlp ZScore remove run=0 score=0.54054 outliers=0.0106
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:22:56] eucalyptus mlp ZScore remove run=1 score=0.58108 outliers=0.0277
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:22:59] eucalyptus mlp ZScore remove run=2 score=0.54730 outliers=0.0298
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:00] eucalyptus mlp ZScore remove run=3 score=0.52027 outliers=0.0298
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/numpy/_core/_methods.py:115: RuntimeWarning: invalid value encountered in clip
#   return um.clip(a, min, max, out=out, **kwargs)
# [2026-03-20 15:23:00] eucalyptus mlp ZScore remove run=4 score=0.58784 outliers=0.0340
# [2026-03-20 15:23:00] RESULT eucalyptus mlp ZScore remove 0.5554 outliers=0.0264
# [2026-03-20 15:23:00] RUN 147/360 eucalyptus mlp ZScore clip
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/numpy/_core/_methods.py:115: RuntimeWarning: invalid value encountered in clip
#   return um.clip(a, min, max, out=out, **kwargs)
# [2026-03-20 15:23:01] eucalyptus mlp ZScore clip run=0 score=0.52703 outliers=0.1766
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/numpy/_core/_methods.py:115: RuntimeWarning: invalid value encountered in clip
#   return um.clip(a, min, max, out=out, **kwargs)
# [2026-03-20 15:23:02] eucalyptus mlp ZScore clip run=1 score=0.55405 outliers=0.1532
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/numpy/_core/_methods.py:115: RuntimeWarning: invalid value encountered in clip
#   return um.clip(a, min, max, out=out, **kwargs)
# [2026-03-20 15:23:02] eucalyptus mlp ZScore clip run=2 score=0.54054 outliers=0.1915
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/numpy/_core/_methods.py:115: RuntimeWarning: invalid value encountered in clip
#   return um.clip(a, min, max, out=out, **kwargs)
# [2026-03-20 15:23:03] eucalyptus mlp ZScore clip run=3 score=0.55405 outliers=0.1957
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:04] eucalyptus mlp ZScore clip run=4 score=0.53378 outliers=0.1957
# [2026-03-20 15:23:04] RESULT eucalyptus mlp ZScore clip 0.5419 outliers=0.1826
# [2026-03-20 15:23:04] RUN 148/360 eucalyptus mlp Percentile remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:04] eucalyptus mlp Percentile remove run=0 score=0.43243 outliers=0.2936
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:05] eucalyptus mlp Percentile remove run=1 score=0.50000 outliers=0.3319
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:05] eucalyptus mlp Percentile remove run=2 score=0.37162 outliers=0.3234
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:05] eucalyptus mlp Percentile remove run=3 score=0.42568 outliers=0.3426
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/numpy/_core/_methods.py:115: RuntimeWarning: invalid value encountered in clip
#   return um.clip(a, min, max, out=out, **kwargs)
# [2026-03-20 15:23:06] eucalyptus mlp Percentile remove run=4 score=0.48649 outliers=0.3404
# [2026-03-20 15:23:06] RESULT eucalyptus mlp Percentile remove 0.4432 outliers=0.3264
# [2026-03-20 15:23:06] RUN 149/360 eucalyptus mlp Percentile clip
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/numpy/_core/_methods.py:115: RuntimeWarning: invalid value encountered in clip
#   return um.clip(a, min, max, out=out, **kwargs)
# [2026-03-20 15:23:07] eucalyptus mlp Percentile clip run=0 score=0.46622 outliers=0.3894
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/numpy/_core/_methods.py:115: RuntimeWarning: invalid value encountered in clip
#   return um.clip(a, min, max, out=out, **kwargs)
# [2026-03-20 15:23:07] eucalyptus mlp Percentile clip run=1 score=0.48649 outliers=0.3745
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/numpy/_core/_methods.py:115: RuntimeWarning: invalid value encountered in clip
#   return um.clip(a, min, max, out=out, **kwargs)
# [2026-03-20 15:23:08] eucalyptus mlp Percentile clip run=2 score=0.43919 outliers=0.4277
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/numpy/_core/_methods.py:115: RuntimeWarning: invalid value encountered in clip
#   return um.clip(a, min, max, out=out, **kwargs)
# [2026-03-20 15:23:09] eucalyptus mlp Percentile clip run=3 score=0.45946 outliers=0.4064
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:09] eucalyptus mlp Percentile clip run=4 score=0.46622 outliers=0.4404
# [2026-03-20 15:23:09] RESULT eucalyptus mlp Percentile clip 0.4635 outliers=0.4077
# [2026-03-20 15:23:09] RUN 150/360 eucalyptus mlp IsolationForest remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:10] eucalyptus mlp IsolationForest remove run=0 score=0.50676 outliers=0.0511
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:11] eucalyptus mlp IsolationForest remove run=1 score=0.54730 outliers=0.0511
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:12] eucalyptus mlp IsolationForest remove run=2 score=0.56757 outliers=0.0489
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:13] eucalyptus mlp IsolationForest remove run=3 score=0.51351 outliers=0.0511
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:13] eucalyptus mlp IsolationForest remove run=4 score=0.51351 outliers=0.0511
# [2026-03-20 15:23:13] RESULT eucalyptus mlp IsolationForest remove 0.5297 outliers=0.0506
# [2026-03-20 15:23:13] RUN 151/360 eucalyptus mlp LOF remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:14] eucalyptus mlp LOF remove run=0 score=0.57432 outliers=0.0511
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:15] eucalyptus mlp LOF remove run=1 score=0.55405 outliers=0.0511
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:15] eucalyptus mlp LOF remove run=2 score=0.55405 outliers=0.0489
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:16] eucalyptus mlp LOF remove run=3 score=0.51351 outliers=0.0511
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:16] eucalyptus mlp LOF remove run=4 score=0.53378 outliers=0.0511
# [2026-03-20 15:23:16] RESULT eucalyptus mlp LOF remove 0.5459 outliers=0.0506
# [2026-03-20 15:23:16] RUN 152/360 eucalyptus mlp Autoencoder remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:17] eucalyptus mlp Autoencoder remove run=0 score=0.52027 outliers=0.0511
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 15:23:18] eucalyptus mlp Autoencoder remove run=1 score=0.53378 outliers=0.0553
# ...
#   warnings.warn(
# [2026-03-20 16:10:53] vehicle mlp Percentile clip run=3 score=0.81765 outliers=0.5204
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:10:53] vehicle mlp Percentile clip run=4 score=0.78235 outliers=0.5204
# [2026-03-20 16:10:53] RESULT vehicle mlp Percentile clip 0.7835 outliers=0.5122
# [2026-03-20 16:10:53] RUN 342/360 vehicle mlp IsolationForest remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:10:54] vehicle mlp IsolationForest remove run=0 score=0.84118 outliers=0.0500
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:10:55] vehicle mlp IsolationForest remove run=1 score=0.76471 outliers=0.0500
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:10:55] vehicle mlp IsolationForest remove run=2 score=0.78235 outliers=0.0481
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:10:56] vehicle mlp IsolationForest remove run=3 score=0.83529 outliers=0.0500
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:10:57] vehicle mlp IsolationForest remove run=4 score=0.78824 outliers=0.0500
# [2026-03-20 16:10:57] RESULT vehicle mlp IsolationForest remove 0.8024 outliers=0.0496
# [2026-03-20 16:10:57] RUN 343/360 vehicle mlp LOF remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:10:57] vehicle mlp LOF remove run=0 score=0.82941 outliers=0.0500
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:10:58] vehicle mlp LOF remove run=1 score=0.78235 outliers=0.0500
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:10:58] vehicle mlp LOF remove run=2 score=0.77059 outliers=0.0500
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:10:59] vehicle mlp LOF remove run=3 score=0.81176 outliers=0.0500
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:10:59] vehicle mlp LOF remove run=4 score=0.78824 outliers=0.0500
# [2026-03-20 16:10:59] RESULT vehicle mlp LOF remove 0.7965 outliers=0.0500
# [2026-03-20 16:10:59] RUN 344/360 vehicle mlp Autoencoder remove
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:11:00] vehicle mlp Autoencoder remove run=0 score=0.82941 outliers=0.0537
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:11:00] vehicle mlp Autoencoder remove run=1 score=0.78235 outliers=0.0519
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:11:01] vehicle mlp Autoencoder remove run=2 score=0.76471 outliers=0.0500
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:11:01] vehicle mlp Autoencoder remove run=3 score=0.83529 outliers=0.0519
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [2026-03-20 16:11:02] vehicle mlp Autoencoder remove run=4 score=0.80588 outliers=0.0537
# [2026-03-20 16:11:02] RESULT vehicle mlp Autoencoder remove 0.8035 outliers=0.0522
# [2026-03-20 16:11:02] RUN 345/360 vehicle xgboost None remove
# [2026-03-20 16:11:02] vehicle xgboost None remove run=0 score=0.72941 outliers=0.0000
# [2026-03-20 16:11:02] vehicle xgboost None remove run=1 score=0.78235 outliers=0.0000
# [2026-03-20 16:11:02] vehicle xgboost None remove run=2 score=0.69412 outliers=0.0000
# [2026-03-20 16:11:02] vehicle xgboost None remove run=3 score=0.75294 outliers=0.0000
# [2026-03-20 16:11:02] vehicle xgboost None remove run=4 score=0.77059 outliers=0.0000
# [2026-03-20 16:11:02] RESULT vehicle xgboost None remove 0.7459 outliers=0.0000
# [2026-03-20 16:11:02] RUN 346/360 vehicle xgboost ZScore remove
# [2026-03-20 16:11:02] vehicle xgboost ZScore remove run=0 score=0.72353 outliers=0.0241
# [2026-03-20 16:11:03] vehicle xgboost ZScore remove run=1 score=0.73529 outliers=0.0352
# [2026-03-20 16:11:03] vehicle xgboost ZScore remove run=2 score=0.71765 outliers=0.0444
# [2026-03-20 16:11:03] vehicle xgboost ZScore remove run=3 score=0.74118 outliers=0.0296
# [2026-03-20 16:11:03] vehicle xgboost ZScore remove run=4 score=0.75294 outliers=0.0278
# [2026-03-20 16:11:03] RESULT vehicle xgboost ZScore remove 0.7341 outliers=0.0322
# [2026-03-20 16:11:03] RUN 347/360 vehicle xgboost ZScore clip
# [2026-03-20 16:11:03] vehicle xgboost ZScore clip run=0 score=0.72941 outliers=0.0241
# [2026-03-20 16:11:03] vehicle xgboost ZScore clip run=1 score=0.78235 outliers=0.0352
# [2026-03-20 16:11:03] vehicle xgboost ZScore clip run=2 score=0.69412 outliers=0.0444
# [2026-03-20 16:11:04] vehicle xgboost ZScore clip run=3 score=0.75294 outliers=0.0296
# [2026-03-20 16:11:04] vehicle xgboost ZScore clip run=4 score=0.77059 outliers=0.0278
# [2026-03-20 16:11:04] RESULT vehicle xgboost ZScore clip 0.7459 outliers=0.0322
# [2026-03-20 16:11:04] RUN 348/360 vehicle xgboost Percentile remove
# [2026-03-20 16:11:04] vehicle xgboost Percentile remove run=0 score=0.66471 outliers=0.5000
# [2026-03-20 16:11:04] vehicle xgboost Percentile remove run=1 score=0.63529 outliers=0.5037
# [2026-03-20 16:11:04] vehicle xgboost Percentile remove run=2 score=0.68235 outliers=0.5167
# [2026-03-20 16:11:04] vehicle xgboost Percentile remove run=3 score=0.69412 outliers=0.5204
# [2026-03-20 16:11:04] vehicle xgboost Percentile remove run=4 score=0.68235 outliers=0.5204
# [2026-03-20 16:11:04] RESULT vehicle xgboost Percentile remove 0.6718 outliers=0.5122
# [2026-03-20 16:11:04] RUN 349/360 vehicle xgboost Percentile clip
# [2026-03-20 16:11:04] vehicle xgboost Percentile clip run=0 score=0.71765 outliers=0.5000
# [2026-03-20 16:11:04] vehicle xgboost Percentile clip run=1 score=0.76471 outliers=0.5037
# [2026-03-20 16:11:05] vehicle xgboost Percentile clip run=2 score=0.70588 outliers=0.5167
# [2026-03-20 16:11:05] vehicle xgboost Percentile clip run=3 score=0.75882 outliers=0.5204
# [2026-03-20 16:11:08] vehicle xgboost Percentile clip run=4 score=0.75882 outliers=0.5204
# [2026-03-20 16:11:08] RESULT vehicle xgboost Percentile clip 0.7412 outliers=0.5122
# [2026-03-20 16:11:08] RUN 350/360 vehicle xgboost IsolationForest remove
# [2026-03-20 16:11:08] vehicle xgboost IsolationForest remove run=0 score=0.71176 outliers=0.0500
# [2026-03-20 16:11:08] vehicle xgboost IsolationForest remove run=1 score=0.75882 outliers=0.0500
# [2026-03-20 16:11:08] vehicle xgboost IsolationForest remove run=2 score=0.71176 outliers=0.0481
# [2026-03-20 16:11:09] vehicle xgboost IsolationForest remove run=3 score=0.76471 outliers=0.0500
# [2026-03-20 16:11:09] vehicle xgboost IsolationForest remove run=4 score=0.75294 outliers=0.0500
# [2026-03-20 16:11:09] RESULT vehicle xgboost IsolationForest remove 0.7400 outliers=0.0496
# [2026-03-20 16:11:09] RUN 351/360 vehicle xgboost LOF remove
# [2026-03-20 16:11:09] vehicle xgboost LOF remove run=0 score=0.70000 outliers=0.0500
# [2026-03-20 16:11:09] vehicle xgboost LOF remove run=1 score=0.74118 outliers=0.0500
# [2026-03-20 16:11:09] vehicle xgboost LOF remove run=2 score=0.70000 outliers=0.0500
# [2026-03-20 16:11:10] vehicle xgboost LOF remove run=3 score=0.75882 outliers=0.0500
# [2026-03-20 16:11:10] vehicle xgboost LOF remove run=4 score=0.74706 outliers=0.0500
# [2026-03-20 16:11:10] RESULT vehicle xgboost LOF remove 0.7294 outliers=0.0500
# [2026-03-20 16:11:10] RUN 352/360 vehicle xgboost Autoencoder remove
# [2026-03-20 16:11:10] vehicle xgboost Autoencoder remove run=0 score=0.70000 outliers=0.0537
# [2026-03-20 16:11:10] vehicle xgboost Autoencoder remove run=1 score=0.74706 outliers=0.0519
# [2026-03-20 16:11:10] vehicle xgboost Autoencoder remove run=2 score=0.73529 outliers=0.0500
# [2026-03-20 16:11:10] vehicle xgboost Autoencoder remove run=3 score=0.75882 outliers=0.0519
# [2026-03-20 16:11:10] vehicle xgboost Autoencoder remove run=4 score=0.75294 outliers=0.0537
# [2026-03-20 16:11:10] RESULT vehicle xgboost Autoencoder remove 0.7388 outliers=0.0522
# [2026-03-20 16:11:10] RUN 353/360 vehicle randomforest None remove
# [2026-03-20 16:11:11] vehicle randomforest None remove run=0 score=0.70588 outliers=0.0000
# [2026-03-20 16:11:11] vehicle randomforest None remove run=1 score=0.71176 outliers=0.0000
# [2026-03-20 16:11:11] vehicle randomforest None remove run=2 score=0.68824 outliers=0.0000
# [2026-03-20 16:11:11] vehicle randomforest None remove run=3 score=0.75882 outliers=0.0000
# [2026-03-20 16:11:12] vehicle randomforest None remove run=4 score=0.72941 outliers=0.0000
# [2026-03-20 16:11:12] RESULT vehicle randomforest None remove 0.7188 outliers=0.0000
# [2026-03-20 16:11:12] RUN 354/360 vehicle randomforest ZScore remove
# [2026-03-20 16:11:12] vehicle randomforest ZScore remove run=0 score=0.70588 outliers=0.0241
# [2026-03-20 16:11:12] vehicle randomforest ZScore remove run=1 score=0.70000 outliers=0.0352
# [2026-03-20 16:11:12] vehicle randomforest ZScore remove run=2 score=0.70000 outliers=0.0444
# [2026-03-20 16:11:12] vehicle randomforest ZScore remove run=3 score=0.74706 outliers=0.0296
# [2026-03-20 16:11:13] vehicle randomforest ZScore remove run=4 score=0.74118 outliers=0.0278
# [2026-03-20 16:11:13] RESULT vehicle randomforest ZScore remove 0.7188 outliers=0.0322
# [2026-03-20 16:11:13] RUN 355/360 vehicle randomforest ZScore clip
# [2026-03-20 16:11:13] vehicle randomforest ZScore clip run=0 score=0.71765 outliers=0.0241
# [2026-03-20 16:11:13] vehicle randomforest ZScore clip run=1 score=0.72353 outliers=0.0352
# [2026-03-20 16:11:13] vehicle randomforest ZScore clip run=2 score=0.68235 outliers=0.0444
# [2026-03-20 16:11:14] vehicle randomforest ZScore clip run=3 score=0.75294 outliers=0.0296
# [2026-03-20 16:11:14] vehicle randomforest ZScore clip run=4 score=0.74118 outliers=0.0278
# [2026-03-20 16:11:14] RESULT vehicle randomforest ZScore clip 0.7235 outliers=0.0322
# [2026-03-20 16:11:14] RUN 356/360 vehicle randomforest Percentile remove
# [2026-03-20 16:11:14] vehicle randomforest Percentile remove run=0 score=0.68235 outliers=0.5000
# [2026-03-20 16:11:14] vehicle randomforest Percentile remove run=1 score=0.65294 outliers=0.5037
# [2026-03-20 16:11:14] vehicle randomforest Percentile remove run=2 score=0.68824 outliers=0.5167
# [2026-03-20 16:11:15] vehicle randomforest Percentile remove run=3 score=0.70588 outliers=0.5204
# [2026-03-20 16:11:15] vehicle randomforest Percentile remove run=4 score=0.68235 outliers=0.5204
# [2026-03-20 16:11:15] RESULT vehicle randomforest Percentile remove 0.6824 outliers=0.5122
# [2026-03-20 16:11:15] RUN 357/360 vehicle randomforest Percentile clip
# [2026-03-20 16:11:15] vehicle randomforest Percentile clip run=0 score=0.71765 outliers=0.5000
# [2026-03-20 16:11:15] vehicle randomforest Percentile clip run=1 score=0.72353 outliers=0.5037
# [2026-03-20 16:11:15] vehicle randomforest Percentile clip run=2 score=0.70000 outliers=0.5167
# [2026-03-20 16:11:16] vehicle randomforest Percentile clip run=3 score=0.75882 outliers=0.5204
# [2026-03-20 16:11:16] vehicle randomforest Percentile clip run=4 score=0.71765 outliers=0.5204
# [2026-03-20 16:11:16] RESULT vehicle randomforest Percentile clip 0.7235 outliers=0.5122
# [2026-03-20 16:11:16] RUN 358/360 vehicle randomforest IsolationForest remove
# [2026-03-20 16:11:16] vehicle randomforest IsolationForest remove run=0 score=0.71176 outliers=0.0500
# [2026-03-20 16:11:17] vehicle randomforest IsolationForest remove run=1 score=0.71176 outliers=0.0500
# [2026-03-20 16:11:17] vehicle randomforest IsolationForest remove run=2 score=0.71765 outliers=0.0481
# [2026-03-20 16:11:17] vehicle randomforest IsolationForest remove run=3 score=0.74706 outliers=0.0500
# [2026-03-20 16:11:18] vehicle randomforest IsolationForest remove run=4 score=0.72941 outliers=0.0500
# [2026-03-20 16:11:18] RESULT vehicle randomforest IsolationForest remove 0.7235 outliers=0.0496
# [2026-03-20 16:11:18] RUN 359/360 vehicle randomforest LOF remove
# [2026-03-20 16:11:18] vehicle randomforest LOF remove run=0 score=0.71176 outliers=0.0500
# [2026-03-20 16:11:18] vehicle randomforest LOF remove run=1 score=0.72353 outliers=0.0500
# [2026-03-20 16:11:18] vehicle randomforest LOF remove run=2 score=0.67647 outliers=0.0500
# [2026-03-20 16:11:19] vehicle randomforest LOF remove run=3 score=0.74706 outliers=0.0500
# [2026-03-20 16:11:19] vehicle randomforest LOF remove run=4 score=0.72941 outliers=0.0500
# [2026-03-20 16:11:19] RESULT vehicle randomforest LOF remove 0.7176 outliers=0.0500
# [2026-03-20 16:11:19] RUN 360/360 vehicle randomforest Autoencoder remove
# [2026-03-20 16:11:19] vehicle randomforest Autoencoder remove run=0 score=0.72941 outliers=0.0537
# [2026-03-20 16:11:19] vehicle randomforest Autoencoder remove run=1 score=0.67647 outliers=0.0519
# [2026-03-20 16:11:20] vehicle randomforest Autoencoder remove run=2 score=0.67647 outliers=0.0500
# [2026-03-20 16:11:20] vehicle randomforest Autoencoder remove run=3 score=0.76471 outliers=0.0519
# [2026-03-20 16:11:20] vehicle randomforest Autoencoder remove run=4 score=0.74118 outliers=0.0537
# [2026-03-20 16:11:20] RESULT vehicle randomforest Autoencoder remove 0.7176 outliers=0.0522
# [2026-03-20 16:11:20] Experiment finished

# %%
res = run_experiment(
    dataset="electricity",
    model="xgboost",
    outlier=None
)

print("\nRESULT:")
print("Mean:", res["mean"])
print("Std:", res["std"])
print("All runs:", res["all"])
# Out:
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:51] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:27:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# RESULT:
# Mean: 0.7837360697340836
# Std: 0.0
# All runs: [0.7837360697340836, 0.7837360697340836, 0.7837360697340836, 0.7837360697340836, 0.7837360697340836]

# %%
run_experiment("cmc","mlp",None)
# Out:
# {'mean': np.float64(0.5850847457627119),
#  'std': np.float64(0.007906375450637698),
#  'min': np.float64(0.576271186440678),
#  'max': np.float64(0.5966101694915255),
#  'removed_mean': np.float64(0.0),
#  'time_mean': np.float64(0.26859517097473146),
#  'all': [0.576271186440678,
#   0.5864406779661017,
#   0.5966101694915255,
#   0.5898305084745763,
#   0.576271186440678]}

# %%
run_experiment("eucalyptus","xgboost",None)
run_experiment("eucalyptus","xgboost","ZScore")
# Out:
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:26] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:27] eucalyptus xgboost None run=0 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:27] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:29] eucalyptus xgboost None run=1 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:29] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:30] eucalyptus xgboost None run=2 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:30] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:31] eucalyptus xgboost None run=3 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:32] eucalyptus xgboost None run=4 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:32] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:33] eucalyptus xgboost ZScore run=0 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:33] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:33] eucalyptus xgboost ZScore run=1 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:33] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:34] eucalyptus xgboost ZScore run=2 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:34] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:35] eucalyptus xgboost ZScore run=3 score=0.24324 removed=0 (0.000)
# /home/lisp/code/tabular-nns/env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [14:04:35] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2026-03-19 14:04:36] eucalyptus xgboost ZScore run=4 score=0.24324 removed=0 (0.000)
# {'mean': np.float64(0.24324324324324326),
#  'std': np.float64(0.0),
#  'min': np.float64(0.24324324324324326),
#  'max': np.float64(0.24324324324324326),
#  'train_size': 470,
#  'removed_mean': np.float64(0.0),
#  'removed_pct': np.float64(0.0),
#  'time_mean': np.float64(0.6785444736480712),
#  'all': [0.24324324324324326,
#   0.24324324324324326,
#   0.24324324324324326,
#   0.24324324324324326,
#   0.24324324324324326]}

# %%
# !pip install torch
# !pip install scikit-learn
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.

# %%
5*5*5
# Out:
# 125

# %%
6*6*6
# Out:
# 216

# %%
125/216
# Out:
# 0.5787037037037037
